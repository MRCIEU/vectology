# %% [markdown]
# # Tests on statistical difference

# %% [markdown]
# This is the analysis notebook on statistical difference of top match results from different models.
#
# - for top matching results (figure 2), use proportions ztest on two binary series
# - for efo-batet scores (figure 3), use kolmogorov-smirnov two sample test on two continuous series

# %%
from pathlib import Path

import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
from itertools import combinations

# %%
df_path = Path("all_top.csv")
assert df_path.exists()
df0 = pd.read_csv(df_path)
print(df0.info())
df0
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1191 entries, 0 to 1190
# Data columns (total 9 columns):
# BLUEBERT-EFO    1191 non-null float64
# BioBERT         1191 non-null float64
# BioSentVec      1191 non-null float64
# BlueBERT        1191 non-null float64
# GUSE            1191 non-null float64
# Spacy           1191 non-null float64
# SciSpacy        1191 non-null float64
# Zooma           1191 non-null float64
# Levenshtein     1191 non-null float64
# dtypes: float64(9)
# memory usage: 83.9 KB
# None
#       BLUEBERT-EFO   BioBERT  BioSentVec  BlueBERT      GUSE     Spacy  \
# 0         0.411765  0.190476    1.000000  0.400000  0.045455  0.053763
# 1         0.185185  1.000000    1.000000  0.305556  0.173913  1.000000
# 2         0.714286  0.076923    0.076923  0.076923  0.117647  0.222222
# 3         0.071429  0.227273    0.105263  0.058824  0.105263  0.105263
# 4         0.800000  0.833333    0.833333  0.833333  1.000000  0.833333
# ...            ...       ...         ...       ...       ...       ...
# 1186      0.800000  0.333333    0.800000  0.888889  0.666667  0.350000
# 1187      1.000000  0.408163    0.689655  0.666667  0.703704  0.666667
# 1188      1.000000  0.555556    0.555556  0.555556  0.555556  0.555556
# 1189      0.142857  0.312500    0.692308  1.000000  0.692308  0.692308
# 1190      1.000000  0.900000    0.062500  0.360000  1.000000  0.142857
#
#       SciSpacy     Zooma  Levenshtein
# 0     1.000000  0.000000     0.400000
# 1     1.000000  0.000000     0.900000
# 2     0.714286  0.076923     0.086957
# 3     0.105263  0.117647     0.117647
# 4     0.833333  0.500000     0.444444
# ...        ...       ...          ...
# 1186  0.368421  0.470588     0.296296
# 1187  0.703704  0.178571     0.833333
# 1188  0.555556  0.555556     0.555556
# 1189  0.692308  1.000000     1.000000
# 1190  1.000000  1.000000     0.315789
#
# [1191 rows x 9 columns]

# %%
df1 = (
    pd.melt(df0.reset_index(drop=False).rename(columns={"index": "id"}), 
            id_vars=["id"], var_name="model")
    .assign(value_map=lambda df: df["value"].apply(lambda x: 0.0 if x < 1.0 else 1.0))
)
df1
# Out:
#          id         model     value  value_map
# 0         0  BLUEBERT-EFO  0.411765        0.0
# 1         1  BLUEBERT-EFO  0.185185        0.0
# 2         2  BLUEBERT-EFO  0.714286        0.0
# 3         3  BLUEBERT-EFO  0.071429        0.0
# 4         4  BLUEBERT-EFO  0.800000        0.0
# ...     ...           ...       ...        ...
# 10714  1186   Levenshtein  0.296296        0.0
# 10715  1187   Levenshtein  0.833333        0.0
# 10716  1188   Levenshtein  0.555556        0.0
# 10717  1189   Levenshtein  1.000000        1.0
# 10718  1190   Levenshtein  0.315789        0.0
#
# [10719 rows x 4 columns]

# %%
df1.groupby("model").agg({"value_map": [lambda s: s.sum(), lambda s: s.sum() / len(s) * 100]})
# Out:
#               value_map
#              <lambda_0> <lambda_1>
# model
# BLUEBERT-EFO      462.0  38.790932
# BioBERT           343.0  28.799328
# BioSentVec        480.0  40.302267
# BlueBERT          347.0  29.135181
# GUSE              341.0  28.631402
# Levenshtein       266.0  22.334173
# SciSpacy          435.0  36.523929
# Spacy             340.0  28.547439
# Zooma             442.0  37.111671

# %%
combs = list(combinations(df1["model"].drop_duplicates().tolist(), 2))

# %% [markdown]
# ## tests on top matching

# %%
# https://www.statsmodels.org/devel/generated/statsmodels.stats.proportion.proportions_ztest.html
df_prop_ztest = pd.DataFrame([
    {
        "series0": series0,
        "series1": series1,
        "test_res": proportions_ztest(
            count=np.array([
                df1[df1["model"] == series0]["value_map"].sum(),
                df1[df1["model"] == series1]["value_map"].sum(),
            ]),
            nobs=np.array([
                df1[df1["model"] == series0]["value_map"].pipe(len),
                df1[df1["model"] == series1]["value_map"].pipe(len),
            ])
        )
    }
    for series0, series1 in combs
]).assign(
    test_stat=lambda df: df["test_res"].apply(lambda t: t[0]),
    test_pval=lambda df: df["test_res"].apply(lambda t: t[1]),
    pval_leq_005=lambda df: df["test_pval"].apply(lambda x: x <= 0.05),
    pval_leq_010=lambda df: df["test_pval"].apply(lambda x: x <= 0.10),
).drop(columns=["test_res"])
df_prop_ztest
# Out:
#          series0      series1  test_stat     test_pval  pval_leq_005  \
# 0   BLUEBERT-EFO      BioBERT   5.154708  2.540267e-07          True
# 1   BLUEBERT-EFO   BioSentVec  -0.754287  4.506768e-01         False
# 2   BLUEBERT-EFO     BlueBERT   4.975424  6.510497e-07          True
# 3   BLUEBERT-EFO         GUSE   5.244540  1.566726e-07          True
# 4   BLUEBERT-EFO        Spacy   5.289504  1.226482e-07          True
# 5   BLUEBERT-EFO     SciSpacy   1.141761  2.535534e-01         False
# 6   BLUEBERT-EFO        Zooma   0.844461  3.984120e-01         False
# 7   BLUEBERT-EFO  Levenshtein   8.717531  2.843336e-18          True
# 8        BioBERT   BioSentVec  -5.902941  3.570772e-09          True
# 9        BioBERT     BlueBERT  -0.180678  8.566200e-01         False
# 10       BioBERT         GUSE   0.090574  9.278310e-01         False
# 11       BioBERT        Spacy   0.135921  8.918841e-01         False
# 12       BioBERT     SciSpacy  -4.019451  5.833394e-05          True
# 13       BioBERT        Zooma  -4.315377  1.593304e-05          True
# 14       BioBERT  Levenshtein   3.616584  2.985162e-04          True
# 15    BioSentVec     BlueBERT   5.724065  1.040048e-08          True
# 16    BioSentVec         GUSE   5.992564  2.065587e-09          True
# 17    BioSentVec        Spacy   6.037421  1.565966e-09          True
# 18    BioSentVec     SciSpacy   1.895648  5.800655e-02         False
# 19    BioSentVec        Zooma   1.598500  1.099318e-01         False
# 20    BioSentVec  Levenshtein   9.454174  3.255825e-21          True
# 21      BlueBERT         GUSE   0.271251  7.861981e-01         False
# 22      BlueBERT        Spacy   0.316596  7.515500e-01         False
# 23      BlueBERT     SciSpacy  -3.839637  1.232163e-04          True
# 24      BlueBERT        Zooma  -4.135691  3.538880e-05          True
# 25      BlueBERT  Levenshtein   3.796311  1.468654e-04          True
# 26          GUSE        Spacy   0.045347  9.638310e-01         False
# 27          GUSE     SciSpacy  -4.109558  3.964174e-05          True
# 28          GUSE        Zooma  -4.405418  1.055800e-05          True
# 29          GUSE  Levenshtein   3.526457  4.211592e-04          True
# 30         Spacy     SciSpacy  -4.154662  3.257688e-05          True
# 31         Spacy        Zooma  -4.450488  8.567518e-06          True
# 32         Spacy  Levenshtein   3.481327  4.989362e-04          True
# 33      SciSpacy        Zooma  -0.297373  7.661821e-01         False
# 34      SciSpacy  Levenshtein   7.598270  3.001158e-14          True
# 35         Zooma  Levenshtein   7.890221  3.016509e-15          True
#
#     pval_leq_010
# 0           True
# 1          False
# 2           True
# 3           True
# 4           True
# 5          False
# 6          False
# 7           True
# 8           True
# 9          False
# 10         False
# 11         False
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18          True
# 19         False
# 20          True
# 21         False
# 22         False
# 23          True
# 24          True
# 25          True
# 26         False
# 27          True
# 28          True
# 29          True
# 30          True
# 31          True
# 32          True
# 33         False
# 34          True
# 35          True

# %% [markdown]
# ## tests on efo-batet scores

# %%
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ks_2samp.html#scipy.stats.ks_2samp
df_ks2samp = pd.DataFrame([
    {
        "series0": series0,
        "series1": series1,
        "test_res": stats.ks_2samp(
            df1[df1["model"] == series0]["value"].to_numpy(),
            df1[df1["model"] == series1]["value"].to_numpy(),
        )
    }
    for series0, series1 in combs
]).assign(
    test_stat=lambda df: df["test_res"].apply(lambda t: t[0]),
    test_pval=lambda df: df["test_res"].apply(lambda t: t[1]),
    pval_leq_005=lambda df: df["test_pval"].apply(lambda x: x <= 0.05),
    pval_leq_010=lambda df: df["test_pval"].apply(lambda x: x <= 0.10),
).drop(columns=["test_res"])
df_ks2samp
# Out:
#          series0      series1  test_stat     test_pval  pval_leq_005  \
# 0   BLUEBERT-EFO      BioBERT   0.142737  5.384227e-11          True
# 1   BLUEBERT-EFO   BioSentVec   0.136020  5.076454e-10          True
# 2   BLUEBERT-EFO     BlueBERT   0.170445  1.610935e-15          True
# 3   BLUEBERT-EFO         GUSE   0.208228  5.229497e-23          True
# 4   BLUEBERT-EFO        Spacy   0.204030  4.229504e-22          True
# 5   BLUEBERT-EFO     SciSpacy   0.130143  3.305194e-09          True
# 6   BLUEBERT-EFO        Zooma   0.203191  6.391052e-22          True
# 7   BLUEBERT-EFO  Levenshtein   0.296390  1.559170e-46          True
# 8        BioBERT   BioSentVec   0.115029  2.784133e-07          True
# 9        BioBERT     BlueBERT   0.042821  2.249447e-01         False
# 10       BioBERT         GUSE   0.074727  2.577408e-03          True
# 11       BioBERT        Spacy   0.075567  2.217255e-03          True
# 12       BioBERT     SciSpacy   0.077246  1.632604e-03          True
# 13       BioBERT        Zooma   0.175483  1.981093e-16          True
# 14       BioBERT  Levenshtein   0.164568  1.717075e-14          True
# 15    BioSentVec     BlueBERT   0.114190  3.504577e-07          True
# 16    BioSentVec         GUSE   0.125105  1.540556e-08          True
# 17    BioSentVec        Spacy   0.126784  9.285698e-09          True
# 18    BioSentVec     SciSpacy   0.055416  5.157918e-02         False
# 19    BioSentVec        Zooma   0.170445  1.610935e-15          True
# 20    BioSentVec  Levenshtein   0.212427  6.188427e-24          True
# 21      BlueBERT         GUSE   0.042821  2.249447e-01         False
# 22      BlueBERT        Spacy   0.050378  9.733019e-02         False
# 23      BlueBERT     SciSpacy   0.077246  1.632604e-03          True
# 24      BlueBERT        Zooma   0.170445  1.610935e-15          True
# 25      BlueBERT  Levenshtein   0.132662  1.496057e-09          True
# 26          GUSE        Spacy   0.019312  9.795153e-01         False
# 27          GUSE     SciSpacy   0.099076  1.650017e-05          True
# 28          GUSE        Zooma   0.170445  1.610935e-15          True
# 29          GUSE  Levenshtein   0.099076  1.650017e-05          True
# 30         Spacy     SciSpacy   0.101595  9.021203e-06          True
# 31         Spacy        Zooma   0.170445  1.610935e-15          True
# 32         Spacy  Levenshtein   0.099076  1.650017e-05          True
# 33      SciSpacy        Zooma   0.170445  1.610935e-15          True
# 34      SciSpacy  Levenshtein   0.192275  1.167227e-19          True
# 35         Zooma  Levenshtein   0.170445  1.610935e-15          True
#
#     pval_leq_010
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9          False
# 10          True
# 11          True
# 12          True
# 13          True
# 14          True
# 15          True
# 16          True
# 17          True
# 18          True
# 19          True
# 20          True
# 21         False
# 22          True
# 23          True
# 24          True
# 25          True
# 26         False
# 27          True
# 28          True
# 29          True
# 30          True
# 31          True
# 32          True
# 33          True
# 34          True
# 35          True

# %% [markdown]
# ## Display

# %%
def format_test_results(row):
    pval = row["test_pval"]
    stat = row["test_stat"]
    star = ""
    if pval <= 0.01:
        star = "***"
    elif pval <= 0.05:
        star = "**"
    elif pval <= 0.1:
        star = "*"
    res = "{stat:.3f}{star} ({pval:.3e})".format(stat=stat, star=star, pval=pval)
    return res

df_disp0 = df_prop_ztest.assign(
    disp=lambda df: df.apply(format_test_results, axis=1)
)[["series0", "series1", "disp"]]

df_disp1 = df_ks2samp.assign(
    disp=lambda df: df.apply(format_test_results, axis=1)
)[["series0", "series1", "disp"]]

df_disp = df_disp0.rename(columns={"disp": "prop_ztest"}).merge(
    df_disp1.rename(columns={"disp": "ks2samp"}),
    left_on=["series0", "series1"],
    right_on=["series0", "series1"],
)
df_disp
# Out:
#          series0      series1             prop_ztest               ks2samp
# 0   BLUEBERT-EFO      BioBERT   5.155*** (2.540e-07)  0.143*** (5.384e-11)
# 1   BLUEBERT-EFO   BioSentVec     -0.754 (4.507e-01)  0.136*** (5.076e-10)
# 2   BLUEBERT-EFO     BlueBERT   4.975*** (6.510e-07)  0.170*** (1.611e-15)
# 3   BLUEBERT-EFO         GUSE   5.245*** (1.567e-07)  0.208*** (5.229e-23)
# 4   BLUEBERT-EFO        Spacy   5.290*** (1.226e-07)  0.204*** (4.230e-22)
# 5   BLUEBERT-EFO     SciSpacy      1.142 (2.536e-01)  0.130*** (3.305e-09)
# 6   BLUEBERT-EFO        Zooma      0.844 (3.984e-01)  0.203*** (6.391e-22)
# 7   BLUEBERT-EFO  Levenshtein   8.718*** (2.843e-18)  0.296*** (1.559e-46)
# 8        BioBERT   BioSentVec  -5.903*** (3.571e-09)  0.115*** (2.784e-07)
# 9        BioBERT     BlueBERT     -0.181 (8.566e-01)     0.043 (2.249e-01)
# 10       BioBERT         GUSE      0.091 (9.278e-01)  0.075*** (2.577e-03)
# 11       BioBERT        Spacy      0.136 (8.919e-01)  0.076*** (2.217e-03)
# 12       BioBERT     SciSpacy  -4.019*** (5.833e-05)  0.077*** (1.633e-03)
# 13       BioBERT        Zooma  -4.315*** (1.593e-05)  0.175*** (1.981e-16)
# 14       BioBERT  Levenshtein   3.617*** (2.985e-04)  0.165*** (1.717e-14)
# 15    BioSentVec     BlueBERT   5.724*** (1.040e-08)  0.114*** (3.505e-07)
# 16    BioSentVec         GUSE   5.993*** (2.066e-09)  0.125*** (1.541e-08)
# 17    BioSentVec        Spacy   6.037*** (1.566e-09)  0.127*** (9.286e-09)
# 18    BioSentVec     SciSpacy     1.896* (5.801e-02)    0.055* (5.158e-02)
# 19    BioSentVec        Zooma      1.598 (1.099e-01)  0.170*** (1.611e-15)
# 20    BioSentVec  Levenshtein   9.454*** (3.256e-21)  0.212*** (6.188e-24)
# 21      BlueBERT         GUSE      0.271 (7.862e-01)     0.043 (2.249e-01)
# 22      BlueBERT        Spacy      0.317 (7.516e-01)    0.050* (9.733e-02)
# 23      BlueBERT     SciSpacy  -3.840*** (1.232e-04)  0.077*** (1.633e-03)
# 24      BlueBERT        Zooma  -4.136*** (3.539e-05)  0.170*** (1.611e-15)
# 25      BlueBERT  Levenshtein   3.796*** (1.469e-04)  0.133*** (1.496e-09)
# 26          GUSE        Spacy      0.045 (9.638e-01)     0.019 (9.795e-01)
# 27          GUSE     SciSpacy  -4.110*** (3.964e-05)  0.099*** (1.650e-05)
# 28          GUSE        Zooma  -4.405*** (1.056e-05)  0.170*** (1.611e-15)
# 29          GUSE  Levenshtein   3.526*** (4.212e-04)  0.099*** (1.650e-05)
# 30         Spacy     SciSpacy  -4.155*** (3.258e-05)  0.102*** (9.021e-06)
# 31         Spacy        Zooma  -4.450*** (8.568e-06)  0.170*** (1.611e-15)
# 32         Spacy  Levenshtein   3.481*** (4.989e-04)  0.099*** (1.650e-05)
# 33      SciSpacy        Zooma     -0.297 (7.662e-01)  0.170*** (1.611e-15)
# 34      SciSpacy  Levenshtein   7.598*** (3.001e-14)  0.192*** (1.167e-19)
# 35         Zooma  Levenshtein   7.890*** (3.017e-15)  0.170*** (1.611e-15)
