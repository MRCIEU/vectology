# %%
import spacy

from funcs.data_processing.stage1_processing import get_ebi_data

# %%
ebi_data = get_ebi_data(verbose=False)
print(ebi_data.info())
ebi_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1191 entries, 0 to 1190
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   query              1191 non-null   object
#  1   MAPPED_TERM_LABEL  1191 non-null   object
#  2   MAPPED_TERM_URI    1191 non-null   object
#  3   MAPPING_TYPE       1191 non-null   object
#  4   id                 1191 non-null   object
#  5   full_id            1191 non-null   object
#  6   mapping_id         1191 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 65.3+ KB
# None
#                                                   query  \
# 0                                          gonarthrosis
# 1              psoriatic and enteropathic arthropathies
# 2                      pain associated with micturition
# 3                                            other mood
# 4                                      preterm delivery
# ...                                                 ...
# 1186   malignant neoplasm without specification of site
# 1187  other and unspecified types of non-hodgkin's l...
# 1188                                        candidiasis
# 1189  other predominantly sexually transmitted disea...
# 1190                   other disorders of adrenal gland
#
#                            MAPPED_TERM_LABEL MAPPED_TERM_URI MAPPING_TYPE  \
# 0                     osteoarthritis || knee     EFO_0004616        Broad
# 1                        psoriatic arthritis     EFO_0003778      ? Broad
# 2                                    dysuria     EFO_0003901      ? Broad
# 3                              mood disorder     EFO_0004247      ? Broad
# 4                            premature birth     EFO_0003917      ? Exact
# ...                                      ...             ...          ...
# 1186                                  cancer     EFO_0000311        Broad
# 1187                   non-Hodgkins lymphoma     EFO_0005952        Exact
# 1188                   Candidiasis, Invasive     EFO_1001283       Narrow
# 1189  bacterial sexually transmitted disease     EFO_0003955       Narrow
# 1190                   adrenal gland disease     EFO_0005539        Exact
#
#                id                               full_id  mapping_id
# 0     EFO_0004616  http://www.ebi.ac.uk/efo/EFO_0004616           1
# 1     EFO_0003778  http://www.ebi.ac.uk/efo/EFO_0003778           2
# 2     EFO_0003901  http://www.ebi.ac.uk/efo/EFO_0003901           3
# 3     EFO_0004247  http://www.ebi.ac.uk/efo/EFO_0004247           4
# 4     EFO_0003917  http://www.ebi.ac.uk/efo/EFO_0003917           5
# ...           ...                                   ...         ...
# 1186  EFO_0000311  http://www.ebi.ac.uk/efo/EFO_0000311        1187
# 1187  EFO_0005952  http://www.ebi.ac.uk/efo/EFO_0005952        1188
# 1188  EFO_1001283  http://www.ebi.ac.uk/efo/EFO_1001283        1189
# 1189  EFO_0003955  http://www.ebi.ac.uk/efo/EFO_0003955        1190
# 1190  EFO_0005539  http://www.ebi.ac.uk/efo/EFO_0005539        1191
#
# [1191 rows x 7 columns]

# %%
SAMPLE_SIZE = 50
ebi_sample = ebi_data[ebi_data["MAPPING_TYPE"] == "Exact"] \
    [["query", "MAPPED_TERM_LABEL", "MAPPED_TERM_URI"]] \
    .head(SAMPLE_SIZE).drop_duplicates().reset_index(drop=True)
ebi_sample
# Out:
#                                                 query  \
# 0                                 alzheimer s disease
# 1                      endocarditis valve unspecified
# 2                  family history of other conditions
# 3                   unspecified maternal hypertension
# 4   stroke not specified as haemorrhage or infarction
# 5                            subarachnoid haemorrhage
# 6            unspecified human immunodeficiency virus
# 7                           other endocrine disorders
# 8                             other diseases of liver
# 9                        primary disorders of muscles
# 10                  pervasive developmental disorders
# 11                     other cerebrovascular diseases
# 12                      other diseases of gallbladder
# 13                fracture of spine level unspecified
# 14                                  acute hepatitis b
# 15                        abnormalities of heart beat
# 16            other congenital malformations of heart
# 17        disorders of tooth development and eruption
# 18                          intracerebral haemorrhage
# 19                     retinal detachments and breaks
# 20                     tuberculosis of nervous system
# 21                                  acute hepatitis a
# 22                                  hookworm diseases
# 23                                    sleep disorders
# 24                        diseases of salivary glands
# 25                          gender identity disorders
# 26                      polyp of female genital tract
# 27                                    persistent mood
# 28                         disorders of vitreous body
# 29                          other coagulation defects
# 30  granulomatous disorders of skin and subcutaneo...
# 31                    excessive vomiting in pregnancy
# 32                   hyperfunction of pituitary gland
# 33                     other nutritional deficiencies
# 34                     other rheumatic heart diseases
# 35                                other helminthiases
# 36                 unspecified viral infection of cns
# 37                  diverticular disease of intestine
# 38                   premature separation of placenta
# 39                                 retention of urine
# 40                   unspecified urinary incontinence
# 41                               isolated proteinuria
# 42                                visual disturbances
# 43                               unspecified dementia
# 44                             unspecified haematuria
# 45                            iron deficiency anaemia
# 46                                acute renal failure
# 47                          nonspecific lymphadenitis
# 48                                    senile cataract
# 49                    reduction defects of lower limb
#
#                                     MAPPED_TERM_LABEL MAPPED_TERM_URI
# 0                                 Alzheimer's disease     EFO_0000249
# 1                                        endocarditis     EFO_0000465
# 2                                      family history     EFO_0000493
# 3                                        preeclampsia     EFO_0000668
# 4                                              stroke     EFO_0000712
# 5                             subarachnoid hemorrhage     EFO_0000713
# 6                                       HIV infection     EFO_0000764
# 7                            endocrine system disease     EFO_0001379
# 8                                       liver disease     EFO_0001421
# 9                                    muscular disease     EFO_0002970
# 10  pervasive developmental disorder - not otherwi...     EFO_0003759
# 11                           cerebrovascular disorder     EFO_0003763
# 12                                gallbladder disease     EFO_0003832
# 13                                   spinal fracture'     EFO_0003902
# 14                              hepatitis B infection     EFO_0004197
# 15                                  cardiac arrythmia     EFO_0004269
# 16                      congenital heart malformation     EFO_0005269
# 17                                     tooth agenesis     EFO_0005410
# 18                           intracerebral hemorrhage     EFO_0005669
# 19                                 retinal detachment     EFO_0005773
# 20                central nervous system tuberculosis     EFO_0007199
# 21                                        hepatitis A     EFO_0007305
# 22                        hookworm infectious disease     EFO_0007314
# 23                                     sleep disorder     EFO_0008568
# 24                             salivary gland disease     EFO_0008581
# 25                           gender identity disorder     EFO_0008587
# 26                         female genital tract polyp     EFO_0008622
# 27                                 dysthymic disorder     EFO_0008623
# 28                              vitreous body disease     EFO_0008624
# 29                          blood coagulation disease     EFO_0009314
# 30                           granulomatous dermatitis     EFO_1000705
# 31                             hyperemesis gravidarum     EFO_1000971
# 32                                   hyperpituitarism     EFO_1000973
# 33                     nutritional deficiency disease     EFO_1001067
# 34                            rheumatic heart disease     EFO_1001161
# 35                                      Helminthiasis     EFO_1001342
# 36                   central nervous system infection     EFO_1001456
# 37                                     diverticulitis     EFO_1001460
# 38                                 Abruptio Placentae     EFO_1001754
# 39                                  Urinary retention      HP_0000016
# 40                               Urinary incontinence      HP_0000020
# 41                                        proteinuria      HP_0000093
# 42                                  Visual impairment      HP_0000505
# 43                                           dementia      HP_0000726
# 44                                          hematuria      HP_0000790
# 45                             Iron deficiency anemia      HP_0001891
# 46                                acute kidney injury      HP_0001919
# 47                                      lymphadenitis      HP_0002840
# 48                               age-related cataract      HP_0011141
# 49                                          Hemimelia   Orphanet_2130

# %%
nlp0 = spacy.load("en_core_web_md")
nlp1 = spacy.load("en_core_web_md")
nlp0.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
def clean_text(term, nlp):
    clean_text = " ".join([_.text for _ in nlp(term) if _.pos_ != "PART" and _.text != "s"])
    return clean_text

def get_norm_pattern(term, nlp):
    doc = nlp(clean_text(term=term, nlp=nlp))
    # remove apostrophe
    res = [{"NORM": _.norm_} for _ in doc if _.pos_ != "PART"]
    return res

patterns = [
    {
        "label": "EFO",
        "pattern": get_norm_pattern(_["MAPPED_TERM_LABEL"], nlp=nlp0),
        "id": _["MAPPED_TERM_URI"],
    }
    for _ in ebi_sample.to_dict(orient="records")
]
print(patterns[:3])
# Out:
# [{'label': 'EFO', 'pattern': [{'NORM': 'alzheimer'}, {'NORM': 'disease'}], 'id': 'EFO_0000249'}, {'label': 'EFO', 'pattern': [{'NORM': 'endocarditis'}], 'id': 'EFO_0000465'}, {'label': 'EFO', 'pattern': [{'NORM': 'family'}, {'NORM': 'history'}], 'id': 'EFO_0000493'}]

# %%
ruler = nlp1.add_pipe("entity_ruler")

# %%
ruler.add_patterns(patterns)

# %%
for idx, _ in enumerate(ebi_sample["MAPPED_TERM_LABEL"]):
    print(f"# {idx}: {_}")
    doc = nlp1(clean_text(_, nlp=nlp0))
    for ent in doc.ents:
        print(ent.text, ent.label_, ent.ent_id_)
    print("\n")
# Out:
# # 0: Alzheimer's disease
# Alzheimer disease EFO EFO_0000249
#
#
# # 1: endocarditis
# endocarditis EFO EFO_0000465
#
#
# # 2: family history
# family history EFO EFO_0000493
#
#
# # 3: preeclampsia
# preeclampsia EFO EFO_0000668
#
#
# # 4: stroke
# stroke EFO EFO_0000712
#
#
# # 5: subarachnoid hemorrhage
# subarachnoid hemorrhage EFO EFO_0000713
#
#
# # 6: HIV infection
# HIV infection EFO EFO_0000764
#
#
# # 7: endocrine system disease
# endocrine system disease EFO EFO_0001379
#
#
# # 8: liver disease
# liver disease EFO EFO_0001421
#
#
# # 9: muscular disease
# muscular disease EFO EFO_0002970
#
#
# # 10: pervasive developmental disorder - not otherwise specified
# pervasive developmental disorder - otherwise specified EFO EFO_0003759
#
#
# # 11: cerebrovascular disorder
# cerebrovascular disorder EFO EFO_0003763
#
#
# # 12: gallbladder disease
# gallbladder disease EFO EFO_0003832
#
#
# # 13: spinal fracture'
# spinal fracture ' EFO EFO_0003902
#
#
# # 14: hepatitis B infection
# hepatitis B infection EFO EFO_0004197
#
#
# # 15: cardiac arrythmia
# cardiac arrythmia EFO EFO_0004269
#
#
# # 16: congenital heart malformation
# congenital heart malformation EFO EFO_0005269
#
#
# # 17: tooth agenesis
# tooth agenesis EFO EFO_0005410
#
#
# # 18: intracerebral hemorrhage
# intracerebral hemorrhage EFO EFO_0005669
#
#
# # 19: retinal detachment
# retinal detachment EFO EFO_0005773
#
#
# # 20: central nervous system tuberculosis
# central nervous system tuberculosis EFO EFO_0007199
#
#
# # 21: hepatitis A
# hepatitis A EFO EFO_0007305
#
#
# # 22: hookworm infectious disease
# hookworm infectious disease EFO EFO_0007314
#
#
# # 23: sleep disorder
# sleep disorder EFO EFO_0008568
#
#
# # 24: salivary gland disease
# salivary gland disease EFO EFO_0008581
#
#
# # 25: gender identity disorder
# gender identity disorder EFO EFO_0008587
#
#
# # 26: female genital tract polyp
# female genital tract polyp EFO EFO_0008622
#
#
# # 27: dysthymic disorder
# dysthymic disorder EFO EFO_0008623
#
#
# # 28: vitreous body disease
# vitreous body disease EFO EFO_0008624
#
#
# # 29: blood coagulation disease
# blood coagulation disease EFO EFO_0009314
#
#
# # 30: granulomatous dermatitis
# granulomatous dermatitis EFO EFO_1000705
#
#
# # 31: hyperemesis gravidarum
# hyperemesis gravidarum EFO EFO_1000971
#
#
# # 32: hyperpituitarism
# hyperpituitarism EFO EFO_1000973
#
#
# # 33: nutritional deficiency disease
# nutritional deficiency disease EFO EFO_1001067
#
#
# # 34: rheumatic heart disease
# rheumatic heart disease EFO EFO_1001161
#
#
# # 35: Helminthiasis
# Helminthiasis ORG
#
#
# # 36: central nervous system infection
# central nervous system infection EFO EFO_1001456
#
#
# # 37: diverticulitis
# diverticulitis EFO EFO_1001460
#
#
# # 38: Abruptio Placentae
# Abruptio Placentae PERSON
#
#
# # 39: Urinary retention
# Urinary retention EFO HP_0000016
#
#
# # 40: Urinary incontinence
# Urinary incontinence EFO HP_0000020
#
#
# # 41: proteinuria
# proteinuria EFO HP_0000093
#
#
# # 42: Visual impairment
# Visual impairment EFO HP_0000505
#
#
# # 43: dementia
# dementia EFO HP_0000726
#
#
# # 44: hematuria
# hematuria EFO HP_0000790
#
#
# # 45: Iron deficiency anemia
# Iron deficiency anemia EFO HP_0001891
#
#
# # 46: acute kidney injury
# acute kidney injury EFO HP_0001919
#
#
# # 47: lymphadenitis
# lymphadenitis ORG
#
#
# # 48: age-related cataract
# age - related cataract EFO HP_0011141
#
#
# # 49: Hemimelia
# Hemimelia GPE

# %%
for idx, _ in enumerate(ebi_sample["query"]):
    print(f"# {idx}: {_}")
    doc = nlp1(clean_text(_, nlp=nlp0))
    for ent in doc.ents:
        print(ent.text, ent.label_, ent.ent_id_)
    print("\n")
# Out:
# # 0: alzheimer s disease
# alzheimer disease EFO EFO_0000249
#
#
# # 1: endocarditis valve unspecified
# endocarditis EFO EFO_0000465
#
#
# # 2: family history of other conditions
# family history EFO EFO_0000493
#
#
# # 3: unspecified maternal hypertension
#
#
# # 4: stroke not specified as haemorrhage or infarction
# stroke EFO EFO_0000712
#
#
# # 5: subarachnoid haemorrhage
# subarachnoid haemorrhage EFO EFO_0000713
#
#
# # 6: unspecified human immunodeficiency virus
#
#
# # 7: other endocrine disorders
#
#
# # 8: other diseases of liver
#
#
# # 9: primary disorders of muscles
#
#
# # 10: pervasive developmental disorders
#
#
# # 11: other cerebrovascular diseases
#
#
# # 12: other diseases of gallbladder
#
#
# # 13: fracture of spine level unspecified
#
#
# # 14: acute hepatitis b
#
#
# # 15: abnormalities of heart beat
#
#
# # 16: other congenital malformations of heart
#
#
# # 17: disorders of tooth development and eruption
#
#
# # 18: intracerebral haemorrhage
# intracerebral haemorrhage EFO EFO_0005669
#
#
# # 19: retinal detachments and breaks
#
#
# # 20: tuberculosis of nervous system
#
#
# # 21: acute hepatitis a
# hepatitis a EFO EFO_0007305
#
#
# # 22: hookworm diseases
#
#
# # 23: sleep disorders
#
#
# # 24: diseases of salivary glands
#
#
# # 25: gender identity disorders
#
#
# # 26: polyp of female genital tract
#
#
# # 27: persistent mood
#
#
# # 28: disorders of vitreous body
#
#
# # 29: other coagulation defects
#
#
# # 30: granulomatous disorders of skin and subcutaneous tissue
#
#
# # 31: excessive vomiting in pregnancy
#
#
# # 32: hyperfunction of pituitary gland
#
#
# # 33: other nutritional deficiencies
#
#
# # 34: other rheumatic heart diseases
#
#
# # 35: other helminthiases
#
#
# # 36: unspecified viral infection of cns
# cns ORG
#
#
# # 37: diverticular disease of intestine
#
#
# # 38: premature separation of placenta
#
#
# # 39: retention of urine
#
#
# # 40: unspecified urinary incontinence
# urinary incontinence EFO HP_0000020
#
#
# # 41: isolated proteinuria
# proteinuria EFO HP_0000093
#
#
# # 42: visual disturbances
#
#
# # 43: unspecified dementia
# dementia EFO HP_0000726
#
#
# # 44: unspecified haematuria
#
#
# # 45: iron deficiency anaemia
# iron deficiency anaemia EFO HP_0001891
#
#
# # 46: acute renal failure
#
#
# # 47: nonspecific lymphadenitis
# lymphadenitis EFO HP_0002840
#
#
# # 48: senile cataract
#
#
# # 49: reduction defects of lower limb

# %%
nlp1.to_disk("entity_ruler")

# %%
nlp2 = spacy.load("entity_ruler")

# %%
nlp2.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'entity_ruler']

# %%
for idx, _ in enumerate(ebi_sample["query"]):
    print(f"# {idx}: {_}")
    doc = nlp2(clean_text(_, nlp=nlp0))
    for ent in doc.ents:
        print(ent.text, ent.label_, ent.ent_id_)
    print("\n")
# Out:
# # 0: alzheimer s disease
# alzheimer disease EFO EFO_0000249
#
#
# # 1: endocarditis valve unspecified
# endocarditis EFO EFO_0000465
#
#
# # 2: family history of other conditions
# family history EFO EFO_0000493
#
#
# # 3: unspecified maternal hypertension
#
#
# # 4: stroke not specified as haemorrhage or infarction
# stroke EFO EFO_0000712
#
#
# # 5: subarachnoid haemorrhage
# subarachnoid haemorrhage EFO EFO_0000713
#
#
# # 6: unspecified human immunodeficiency virus
#
#
# # 7: other endocrine disorders
#
#
# # 8: other diseases of liver
#
#
# # 9: primary disorders of muscles
#
#
# # 10: pervasive developmental disorders
#
#
# # 11: other cerebrovascular diseases
#
#
# # 12: other diseases of gallbladder
#
#
# # 13: fracture of spine level unspecified
#
#
# # 14: acute hepatitis b
#
#
# # 15: abnormalities of heart beat
#
#
# # 16: other congenital malformations of heart
#
#
# # 17: disorders of tooth development and eruption
#
#
# # 18: intracerebral haemorrhage
# intracerebral haemorrhage EFO EFO_0005669
#
#
# # 19: retinal detachments and breaks
#
#
# # 20: tuberculosis of nervous system
#
#
# # 21: acute hepatitis a
# hepatitis a EFO EFO_0007305
#
#
# # 22: hookworm diseases
#
#
# # 23: sleep disorders
#
#
# # 24: diseases of salivary glands
#
#
# # 25: gender identity disorders
#
#
# # 26: polyp of female genital tract
#
#
# # 27: persistent mood
#
#
# # 28: disorders of vitreous body
#
#
# # 29: other coagulation defects
#
#
# # 30: granulomatous disorders of skin and subcutaneous tissue
#
#
# # 31: excessive vomiting in pregnancy
#
#
# # 32: hyperfunction of pituitary gland
#
#
# # 33: other nutritional deficiencies
#
#
# # 34: other rheumatic heart diseases
#
#
# # 35: other helminthiases
#
#
# # 36: unspecified viral infection of cns
# cns ORG
#
#
# # 37: diverticular disease of intestine
#
#
# # 38: premature separation of placenta
#
#
# # 39: retention of urine
#
#
# # 40: unspecified urinary incontinence
# urinary incontinence EFO HP_0000020
#
#
# # 41: isolated proteinuria
# proteinuria EFO HP_0000093
#
#
# # 42: visual disturbances
#
#
# # 43: unspecified dementia
# dementia EFO HP_0000726
#
#
# # 44: unspecified haematuria
#
#
# # 45: iron deficiency anaemia
# iron deficiency anaemia EFO HP_0001891
#
#
# # 46: acute renal failure
#
#
# # 47: nonspecific lymphadenitis
# lymphadenitis EFO HP_0002840
#
#
# # 48: senile cataract
#
#
# # 49: reduction defects of lower limb
