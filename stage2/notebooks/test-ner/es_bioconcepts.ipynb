# %%
from typing import List
import json
from pathlib import Path
from pprint import pprint
import re

import pandas as pd
import janitor
import requests
from pydash import py_

from funcs import utils, paths

# %% [markdown]
# ---
# # cleaning

# %%
data_root = utils.find_data_root()
data_dir = data_root / "bioconceptvec"
sample_file_path = data_dir / "bioconcepts2pubtatorcentral.sample"
assert sample_file_path.exists(), sample_file_path

# %%
df_raw = pd \
    .read_csv(
        sample_file_path, sep="\t", 
        names=["idx", "ent_type", "ent_id", "term", "source"]) \
    .dropna().reset_index(drop=True)
df_raw
# Out:
#           idx  ent_type        ent_id                    term     source
# 0     3958000   Species          9606                patients      SR4GN
# 1     3958000   Disease  MESH:D012544  Scheuermann's kyphosis  TaggerOne
# 2    23574000  Chemical  MESH:D008012             Astrazeneca  TaggerOne
# 3    23574000   Species          9615                    dogs      SR4GN
# 4    23574000   Disease  MESH:D007153     antibody omalizumab  TaggerOne
# ..        ...       ...           ...                     ...        ...
# 802  20635000  Mutation   rs779184767                   C243A      tmVar
# 803  20635000      Gene        155030                     Gag  GNormPlus
# 804  20635000      Gene         57379                     AID  GNormPlus
# 805  20635000  Chemical  MESH:D009584                       N  TaggerOne
# 806  20635000  Chemical  MESH:C108952                     Asp  TaggerOne
#
# [807 rows x 5 columns]

# %%
def valid_p(term: str) -> bool:
    """
    - term should be long enough
    - term should not contain digit
    """
    num_char_limit = 2
    if len(term) <= num_char_limit:
        return False
    find_digits = re.findall(r"\d", term)
    if len(find_digits) > 0:
        return False
    return True

def clean_term(term: str) -> List[str]:
    # split by "|"
    terms = term.split("|")
    terms = [_.strip().lower() for _ in terms]
    # drop invalid terms
    terms = [_ for _ in terms if valid_p(_)]
    terms = py_.chain(terms).uniq().value()
    return terms

# %%
df = df_raw \
    .transform_column("term", clean_term, "expand_terms") \
    .explode("expand_terms") \
    .dropna() \
    .drop_duplicates(subset=["ent_id", "expand_terms"])
df
# Out:
#           idx  ent_type        ent_id                    term     source  \
# 0     3958000   Species          9606                patients      SR4GN
# 1     3958000   Disease  MESH:D012544  Scheuermann's kyphosis  TaggerOne
# 2    23574000  Chemical  MESH:D008012             Astrazeneca  TaggerOne
# 3    23574000   Species          9615                    dogs      SR4GN
# 4    23574000   Disease  MESH:D007153     antibody omalizumab  TaggerOne
# ..        ...       ...           ...                     ...        ...
# 800  20635000  Chemical  MESH:C032259  SDS|SDS-polyacrylamide  TaggerOne
# 801  20635000      Gene          1123                     CHn  GNormPlus
# 803  20635000      Gene        155030                     Gag  GNormPlus
# 804  20635000      Gene         57379                     AID  GNormPlus
# 806  20635000  Chemical  MESH:C108952                     Asp  TaggerOne
#
#                expand_terms
# 0                  patients
# 1    scheuermann's kyphosis
# 2               astrazeneca
# 3                      dogs
# 4       antibody omalizumab
# ..                      ...
# 800      sds-polyacrylamide
# 801                     chn
# 803                     gag
# 804                     aid
# 806                     asp
#
# [681 rows x 6 columns]

# %%
df.groupby("expand_terms").size().sort_values()
# Out:
# expand_terms
# (c   o b                      1
# nitrosating amines            1
# non-hodgkin's lymphoma        1
# non-small cell lung cancer    1
# nontuberculous pneumonia      1
#                              ..
# formamide                     1
# zno                           1
# semet                         2
# tuberculosis                  2
# bacteria                      2
# Length: 678, dtype: int64

# %%
df[df.duplicated(keep=False, subset=["expand_terms"])]
# Out:
#           idx  ent_type        ent_id  \
# 66   20760000   Species          1773
# 145   3130000   Disease  MESH:D014376
# 175  31134000   Species             2
# 333  15356000   Species           562
# 497  19448000  Chemical  MESH:D012645
# 561   9853000  Chemical  MESH:C517785
#
#                                         term              source  expand_terms
# 66                              TUBERCULOSIS               SR4GN  tuberculosis
# 145                tuberculosis|Tuberculosis           TaggerOne  tuberculosis
# 175              Bacteria|bacteria|bacterial               SR4GN      bacteria
# 333                Escherichia coli|bacteria               SR4GN      bacteria
# 497  SeMet|Selenomethionine|selenomethionine  TaggerOne|CTD|MESH         semet
# 561                SeMet|seleno-L-methionine           TaggerOne         semet

# %%
df1 = df.drop_duplicates(subset=["expand_terms"])
df1
# Out:
#           idx  ent_type        ent_id                    term     source  \
# 0     3958000   Species          9606                patients      SR4GN
# 1     3958000   Disease  MESH:D012544  Scheuermann's kyphosis  TaggerOne
# 2    23574000  Chemical  MESH:D008012             Astrazeneca  TaggerOne
# 3    23574000   Species          9615                    dogs      SR4GN
# 4    23574000   Disease  MESH:D007153     antibody omalizumab  TaggerOne
# ..        ...       ...           ...                     ...        ...
# 800  20635000  Chemical  MESH:C032259  SDS|SDS-polyacrylamide  TaggerOne
# 801  20635000      Gene          1123                     CHn  GNormPlus
# 803  20635000      Gene        155030                     Gag  GNormPlus
# 804  20635000      Gene         57379                     AID  GNormPlus
# 806  20635000  Chemical  MESH:C108952                     Asp  TaggerOne
#
#                expand_terms
# 0                  patients
# 1    scheuermann's kyphosis
# 2               astrazeneca
# 3                      dogs
# 4       antibody omalizumab
# ..                      ...
# 800      sds-polyacrylamide
# 801                     chn
# 803                     gag
# 804                     aid
# 806                     asp
#
# [678 rows x 6 columns]

# %%
df1[df1.duplicated(keep=False, subset=["expand_terms"])]
# Out:
# Empty DataFrame
# Columns: [idx, ent_type, ent_id, term, source, expand_terms]
# Index: []

# %% [markdown]
# ---
# # indexing

# %%
ES_URL = "http://ieu-mrbssd1.epi.bris.ac.uk:26550"

r = requests.get(ES_URL)
assert r.ok
print(r.json())
# Out:
# {'name': '53d4a935d550', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'cfbqZlymRuas-lywIWKaOg', 'version': {'number': '7.5.1', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '3ae9ac9a93c95bd0cdc054951cf95d88e1e18d96', 'build_date': '2019-12-16T22:57:37.835892Z', 'build_snapshot': False, 'lucene_version': '8.3.0', 'minimum_wire_compatibility_version': '6.8.0', 'minimum_index_compatibility_version': '6.0.0-beta1'}, 'tagline': 'You Know, for Search'}

# %%
INDEX_NAME = "test-bioconcepts"

# %%
index_url = ES_URL + "/" + INDEX_NAME

put_data = {
    "settings": {
        "analysis": {
            "analyzer": {
                "substring": {
                    "type": "custom",
                    "tokenizer": "standard",
                    "filter": [
                        "lowercase",
                        "apostrophe",
                        "kstem",
                        "substring"           
                    ]
                },
                "exact": {
                    "type": "custom",
                    "tokenizer": "keyword",
                    "filter": [
                        "lowercase",
                        "apostrophe",
                        "kstem",
                    ]
                }
            },
            "filter": {
                "substring": {
                    "type":"shingle",
                    "output_unigrams" : True
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "ent_id": {
              "type": "keyword",
            },
            "ent_term": {
                "type": "text",
            },
            "ent_term_norm": {
                "type": "text",
                "analyzer": "exact",
                "search_analyzer": "substring",
            }
        }
    }
}
pprint(put_data)
# Out:
# {'mappings': {'properties': {'ent_id': {'type': 'keyword'},
#                              'ent_term': {'type': 'text'},
#                              'ent_term_norm': {'analyzer': 'exact',
#                                                'search_analyzer': 'substring',
#                                                'type': 'text'}}},
#  'settings': {'analysis': {'analyzer': {'exact': {'filter': ['lowercase',
#                                                              'apostrophe',
#                                                              'kstem'],
#                                                   'tokenizer': 'keyword',
#                                                   'type': 'custom'},
#                                         'substring': {'filter': ['lowercase',
#                                                                  'apostrophe',
#                                                                  'kstem',
#                                                                  'substring'],
#                                                       'tokenizer': 'standard',
#                                                       'type': 'custom'}},
#                            'filter': {'substring': {'output_unigrams': True,
#                                                     'type': 'shingle'}}}}}

# %%
url = ES_URL + f"/{INDEX_NAME}"
r = requests.get(url)
if r.ok:
    print("Remove index")
    r = requests.delete(url)
    
print("Init index")
r = requests.put(url, json=put_data)

# %%
for _ in df1.to_dict(orient="records"):
    ent_id = _["ent_type"] + "_" + _["ent_id"].replace(":", "_")
    ent_term = _["expand_terms"]
    doc = {
        "ent_id": ent_id,
        "ent_term": ent_term,
        "ent_term_norm": ent_term,
    }
    url = ES_URL + f"/{INDEX_NAME}" + "/_doc/"
    r = requests.post(url, json=doc)

# %%
def search_term(term: str):
    search_data = {
        "query": {
            "match": {
                "ent_term_norm": term
            }
        },
        "aggs": {
            "dedup": {
                "terms": {"field": "ent_id"},
                "aggs": {"dedup_docs": {"top_hits": {"size": 1}}}
            }
        }
    }
    # index_name = INDEX_NAME
    index_name = "bioconcepts"
    url = ES_URL + f"/{index_name}" + "/_search"
    r = requests.get(url, json=search_data)
    r.raise_for_status()
    res = r.json()["aggregations"]["dedup"]["buckets"]
    return res

# %%
LABELS = [
    "lung disease",
    "aid",
    "Scheuermann's kyphosis"
]

for idx, label in enumerate(LABELS):
    print(f"#{idx} {label}")
    search_res = search_term(label)
    pprint(search_res)
    print("\n")
# Out:
# #0 lung disease
# [{'dedup_docs': {'hits': {'hits': [{'_id': 'ObIcgoEBh99XIFUo0scP',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.015286,
#                                     '_source': {'ent_id': 'Disease_MESH_D008171',
#                                                 'ent_term': 'lung disease',
#                                                 'ent_term_norm': 'lung '
#                                                                  'disease'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.015286,
#                           'total': {'relation': 'eq', 'value': 551}}},
#   'doc_count': 551,
#   'key': 'Disease_MESH_D008171'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 've-xhYEBh99XIFUoKG_2',
#                                     '_index': 'bioconcepts',
#                                     '_score': 12.41745,
#                                     '_source': {'ent_id': 'Disease_MESH_D003141',
#                                                 'ent_term': 'disease',
#                                                 'ent_term_norm': 'disease'},
#                                     '_type': '_doc'}],
#                           'max_score': 12.41745,
#                           'total': {'relation': 'eq', 'value': 40}}},
#   'doc_count': 40,
#   'key': 'Disease_MESH_D003141'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': '97IZgoEBh99XIFUoqJJ-',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.015286,
#                                     '_source': {'ent_id': 'Gene_100530540',
#                                                 'ent_term': 'lung',
#                                                 'ent_term_norm': 'lung'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.015286,
#                           'total': {'relation': 'eq', 'value': 8}}},
#   'doc_count': 8,
#   'key': 'Gene_100530540'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'ozkJioEBh99XIFUoMjpC',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.015286,
#                                     '_source': {'ent_id': 'Disease_MESH_D000275',
#                                                 'ent_term': 'lung disease',
#                                                 'ent_term_norm': 'lung '
#                                                                  'disease'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.015286,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D000275'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': '0wTohoEBh99XIFUoXhKW',
#                                     '_index': 'bioconcepts',
#                                     '_score': 12.41745,
#                                     '_source': {'ent_id': 'Disease_MESH_D007239',
#                                                 'ent_term': "disease's "
#                                                             'infection',
#                                                 'ent_term_norm': "disease's "
#                                                                  'infection'},
#                                     '_type': '_doc'}],
#                           'max_score': 12.41745,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D007239'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'TRxeiIEBh99XIFUoaOCt',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.015286,
#                                     '_source': {'ent_id': 'Disease_MESH_D009422',
#                                                 'ent_term': "lung' neurologic "
#                                                             'seizures '
#                                                             'transient loss of '
#                                                             'consciousness '
#                                                             'stroke',
#                                                 'ent_term_norm': "lung' "
#                                                                  'neurologic '
#                                                                  'seizures '
#                                                                  'transient '
#                                                                  'loss of '
#                                                                  'consciousness '
#                                                                  'stroke'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.015286,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D009422'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'gBTgh4EBh99XIFUo4pIZ',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.015286,
#                                     '_source': {'ent_id': 'Disease_MESH_D018805',
#                                                 'ent_term': 'lung disease',
#                                                 'ent_term_norm': 'lung '
#                                                                  'disease'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.015286,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D018805'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'n-DJhIEBh99XIFUoNQ1y',
#                                     '_index': 'bioconcepts',
#                                     '_score': 12.41745,
#                                     '_source': {'ent_id': 'Disease_MESH_D028361',
#                                                 'ent_term': "diseases' "
#                                                             'mitochondrial '
#                                                             'dysfunction',
#                                                 'ent_term_norm': "diseases' "
#                                                                  'mitochondrial '
#                                                                  'dysfunction'},
#                                     '_type': '_doc'}],
#                           'max_score': 12.41745,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D028361'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': '_jXYiYEBh99XIFUoavkY',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.015286,
#                                     '_source': {'ent_id': 'Disease_MESH_D055370',
#                                                 'ent_term': "lung's injury",
#                                                 'ent_term_norm': "lung's "
#                                                                  'injury'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.015286,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D055370'}]
#
#
# #1 aid
# [{'dedup_docs': {'hits': {'hits': [{'_id': 'i7IdgoEBh99XIFUoTs9d',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.008918,
#                                     '_source': {'ent_id': 'Gene_57379',
#                                                 'ent_term': 'aid',
#                                                 'ent_term_norm': 'aid'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.008918,
#                           'total': {'relation': 'eq', 'value': 429}}},
#   'doc_count': 429,
#   'key': 'Gene_57379'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'ebMrgoEBh99XIFUogL_K',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.008918,
#                                     '_source': {'ent_id': 'Gene_11628',
#                                                 'ent_term': 'aid',
#                                                 'ent_term_norm': 'aid'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.008918,
#                           'total': {'relation': 'eq', 'value': 28}}},
#   'doc_count': 28,
#   'key': 'Gene_11628'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'iuQMhYEBh99XIFUouYii',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.008918,
#                                     '_source': {'ent_id': 'Gene_399679',
#                                                 'ent_term': 'aid',
#                                                 'ent_term_norm': 'aid'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.008918,
#                           'total': {'relation': 'eq', 'value': 8}}},
#   'doc_count': 8,
#   'key': 'Gene_399679'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'hxThh4EBh99XIFUopZ97',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.008918,
#                                     '_source': {'ent_id': 'Gene_418257',
#                                                 'ent_term': 'aid',
#                                                 'ent_term_norm': 'aid'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.008918,
#                           'total': {'relation': 'eq', 'value': 2}}},
#   'doc_count': 2,
#   'key': 'Gene_418257'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'BrmDgoEBh99XIFUoy5Z1',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.008918,
#                                     '_source': {'ent_id': 'Gene_442983',
#                                                 'ent_term': 'aid',
#                                                 'ent_term_norm': 'aid'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.008918,
#                           'total': {'relation': 'eq', 'value': 2}}},
#   'doc_count': 2,
#   'key': 'Gene_442983'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'idp8hIEBh99XIFUo0P0y',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.008918,
#                                     '_source': {'ent_id': 'Disease_MESH_D003109',
#                                                 'ent_term': "aid's function",
#                                                 'ent_term_norm': "aid's "
#                                                                  'function'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.008918,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D003109'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'hiKsiIEBh99XIFUothLV',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.008918,
#                                     '_source': {'ent_id': 'Disease_MESH_D009894',
#                                                 'ent_term': "aid's "
#                                                             'opportunistic '
#                                                             'infections',
#                                                 'ent_term_norm': "aid's "
#                                                                  'opportunistic '
#                                                                  'infections'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.008918,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D009894'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'djCMiYEBh99XIFUoaOjg',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.008918,
#                                     '_source': {'ent_id': 'Gene_108697151',
#                                                 'ent_term': 'aid',
#                                                 'ent_term_norm': 'aid'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.008918,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Gene_108697151'}]
#
#
# #2 Scheuermann's kyphosis
# [{'dedup_docs': {'hits': {'hits': [{'_id': 'cbIdgoEBh99XIFUoa9EF',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.154463,
#                                     '_source': {'ent_id': 'Disease_MESH_D007738',
#                                                 'ent_term': 'kyphosis',
#                                                 'ent_term_norm': 'kyphosis'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.154463,
#                           'total': {'relation': 'eq', 'value': 405}}},
#   'doc_count': 405,
#   'key': 'Disease_MESH_D007738'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'nbIWgoEBh99XIFUofl24',
#                                     '_index': 'bioconcepts',
#                                     '_score': 12.394195,
#                                     '_source': {'ent_id': 'Disease_MESH_D012544',
#                                                 'ent_term': "scheuermann's "
#                                                             'kyphosis',
#                                                 'ent_term_norm': "scheuermann's "
#                                                                  'kyphosis'},
#                                     '_type': '_doc'}],
#                           'max_score': 12.394195,
#                           'total': {'relation': 'eq', 'value': 42}}},
#   'doc_count': 42,
#   'key': 'Disease_MESH_D012544'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'wdYyhIEBh99XIFUoohXT',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.154463,
#                                     '_source': {'ent_id': 'Chemical_MESH_D005227',
#                                                 'ent_term': 'kyphosis',
#                                                 'ent_term_norm': 'kyphosis'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.154463,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Chemical_MESH_D005227'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'G961hIEBh99XIFUohr9-',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.154463,
#                                     '_source': {'ent_id': 'Disease_MESH_D000275',
#                                                 'ent_term': 'kyphosis',
#                                                 'ent_term_norm': 'kyphosis'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.154463,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D000275'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'MOP9hIEBh99XIFUo9I1x',
#                                     '_index': 'bioconcepts',
#                                     '_score': 12.394195,
#                                     '_source': {'ent_id': 'Disease_MESH_D008569',
#                                                 'ent_term': "scheuermann's "
#                                                             'disease\t'
#                                                             'taggerone',
#                                                 'ent_term_norm': "scheuermann's "
#                                                                  'disease\t'
#                                                                  'taggerone'},
#                                     '_type': '_doc'}],
#                           'max_score': 12.394195,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D008569'},
#  {'dedup_docs': {'hits': {'hits': [{'_id': 'qfC6hYEBh99XIFUoVwv5',
#                                     '_index': 'bioconcepts',
#                                     '_score': 10.154463,
#                                     '_source': {'ent_id': 'Disease_MESH_D009369',
#                                                 'ent_term': 'kyphosis',
#                                                 'ent_term_norm': 'kyphosis'},
#                                     '_type': '_doc'}],
#                           'max_score': 10.154463,
#                           'total': {'relation': 'eq', 'value': 1}}},
#   'doc_count': 1,
#   'key': 'Disease_MESH_D009369'}]

# %%
for idx, _ in list(df_raw.iterrows())[:50]:
    print(f"#{idx} {_['term']}")
    search_res = search_term(_["term"])
    print(search_res)
    print("\n")
# Out:
# #0 patients
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '8bENgoEBh99XIFUoPNaa', '_score': 8.672219, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patient', 'ent_term_norm': 'patient'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '3bENgoEBh99XIFUoO9ZM', '_score': 8.672219, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patients', 'ent_term_norm': 'patients'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '_rISgoEBh99XIFUonjEH', '_score': 8.672219, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patients', 'ent_term_norm': 'patients'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'W7ISgoEBh99XIFUoozKG', '_score': 8.672219, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patient', 'ent_term_norm': 'patient'}}]
#
#
# #1 Scheuermann's kyphosis
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '3rENgoEBh99XIFUoO9Zs', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D012544', 'ent_term': "scheuermann's kyphosis", 'ent_term_norm': "scheuermann's kyphosis"}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '37ENgoEBh99XIFUoO9aA', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D007738', 'ent_term': 'kyphosis', 'ent_term_norm': 'kyphosis'}}]
#
#
# #2 Astrazeneca
# []
#
#
# #3 dogs
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '4LENgoEBh99XIFUoO9aP', '_score': 9.260006, '_source': {'ent_id': 'Species_9615', 'ent_term': 'dogs', 'ent_term_norm': 'dogs'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'qrISgoEBh99XIFUomTEQ', '_score': 9.260006, '_source': {'ent_id': 'Species_9615', 'ent_term': 'dogs', 'ent_term_norm': 'dogs'}}]
#
#
# #4 antibody omalizumab
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '4rENgoEBh99XIFUoO9ay', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D007153', 'ent_term': 'antibody omalizumab', 'ent_term_norm': 'antibody omalizumab'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '67ENgoEBh99XIFUoPNY9', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D000069444', 'ent_term': 'omalizumab', 'ent_term_norm': 'omalizumab'}}]
#
#
# #5 asthma death
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '-bENgoEBh99XIFUoPdYW', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'asthma', 'ent_term_norm': 'asthma'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '-7ENgoEBh99XIFUoPdY1', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'asthma death', 'ent_term_norm': 'asthma death'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'YLITgoEBh99XIFUoLDtU', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'asthma', 'ent_term_norm': 'asthma'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '7LENgoEBh99XIFUoadnr', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D003643', 'ent_term': 'deaths', 'ent_term_norm': 'deaths'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'pLENgoEBh99XIFUoVtin', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D003643', 'ent_term': 'death', 'ent_term_norm': 'death'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '6bISgoEBh99XIFUorDI1', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D003643', 'ent_term': 'deaths', 'ent_term_norm': 'deaths'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'prISgoEBh99XIFUomDHU', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D003643', 'ent_term': 'death', 'ent_term_norm': 'death'}}]
#
#
# #6 hyperventilation
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '47ENgoEBh99XIFUoO9bC', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D006985', 'ent_term': 'hyperventilation', 'ent_term_norm': 'hyperventilation'}}]
#
#
# #7 theophyllines|theophylline
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '5LENgoEBh99XIFUoO9bS', '_score': 18.520012, '_source': {'ent_id': 'Chemical_MESH_D013806', 'ent_term': 'theophyllines', 'ent_term_norm': 'theophyllines'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'k7ITgoEBh99XIFUoIDpF', '_score': 18.520012, '_source': {'ent_id': 'Chemical_MESH_D013806', 'ent_term': 'theophylline', 'ent_term_norm': 'theophylline'}}]
#
#
# #8 lung disease
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '6rENgoEBh99XIFUoPNYt', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D008171', 'ent_term': 'lung disease', 'ent_term_norm': 'lung disease'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'OLIQgoEBh99XIFUoYAww', '_score': 9.770832, '_source': {'ent_id': 'Gene_100530540', 'ent_term': 'lung', 'ent_term_norm': 'lung'}}]
#
#
# #9 tacrolimus
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '7rENgoEBh99XIFUoPNZr', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D016559', 'ent_term': 'tacrolimus', 'ent_term_norm': 'tacrolimus'}}]
#
#
# #10 bronchiectasis
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'V7EOgoEBh99XIFUocess', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D001987', 'ent_term': 'bronchiectasis', 'ent_term_norm': 'bronchiectasis'}}]
#
#
# #11 ciclosporin
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '77ENgoEBh99XIFUoPNZ7', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D016572', 'ent_term': 'ciclosporin', 'ent_term_norm': 'ciclosporin'}}]
#
#
# #12 patient|Patients|patients|Male|children|Patient|males
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '8bENgoEBh99XIFUoPNaa', '_score': 34.688877, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patient', 'ent_term_norm': 'patient'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '3bENgoEBh99XIFUoO9ZM', '_score': 34.688877, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patients', 'ent_term_norm': 'patients'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '_rISgoEBh99XIFUonjEH', '_score': 34.688877, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patients', 'ent_term_norm': 'patients'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'W7ISgoEBh99XIFUoozKG', '_score': 34.688877, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patient', 'ent_term_norm': 'patient'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '8rENgoEBh99XIFUoPNap', '_score': 9.260006, '_source': {'ent_id': 'Species_9606', 'ent_term': 'children', 'ent_term_norm': 'children'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'C7ISgoEBh99XIFUonjLM', '_score': 9.260006, '_source': {'ent_id': 'Species_9606', 'ent_term': 'children', 'ent_term_norm': 'children'}}]
#
#
# #13 salicylate
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '87ENgoEBh99XIFUoPNa3', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D012459', 'ent_term': 'salicylate', 'ent_term_norm': 'salicylate'}}]
#
#
# #14 prednisolone
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '9LENgoEBh99XIFUoPNbH', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D011239', 'ent_term': 'prednisolone', 'ent_term_norm': 'prednisolone'}}]
#
#
# #15 H0721
# []
#
#
# #16 corticosteroid|OCS|corticosteroids
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '6LENgoEBh99XIFUoPNYQ', '_score': 9.770832, '_source': {'ent_id': 'Chemical_-', 'ent_term': 'ocs', 'ent_term_norm': 'ocs'}}]
#
#
# #17 bambuterol
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '9bENgoEBh99XIFUoPNbX', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_C047766', 'ent_term': 'bambuterol', 'ent_term_norm': 'bambuterol'}}]
#
#
# #18 methylprednisolone
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '9rENgoEBh99XIFUoPNbm', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D008775', 'ent_term': 'methylprednisolone', 'ent_term_norm': 'methylprednisolone'}}]
#
#
# #19 azathioprine
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '97ENgoEBh99XIFUoPNb2', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D001379', 'ent_term': 'azathioprine', 'ent_term_norm': 'azathioprine'}}]
#
#
# #20 asthma|Asthma|asthma within|Omalizumab for asthma|Omalizumab in Severe Asthma
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '-bENgoEBh99XIFUoPdYW', '_score': 46.30003, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'asthma', 'ent_term_norm': 'asthma'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'YLITgoEBh99XIFUoLDtU', '_score': 46.30003, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'asthma', 'ent_term_norm': 'asthma'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '67ENgoEBh99XIFUoPNY9', '_score': 19.541664, '_source': {'ent_id': 'Chemical_MESH_D000069444', 'ent_term': 'omalizumab', 'ent_term_norm': 'omalizumab'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'Q7ISgoEBh99XIFUoByi2', '_score': 18.520012, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'asthma asthma', 'ent_term_norm': 'asthma asthma'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'KLIQgoEBh99XIFUoMgk2', '_score': 9.770832, '_source': {'ent_id': 'Gene_435', 'ent_term': 'for', 'ent_term_norm': 'for'}}]
#
#
# #21 leukotriene
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'I7IQgoEBh99XIFUoXgzy', '_score': 9.260006, '_source': {'ent_id': 'Chemical_MESH_D015289', 'ent_term': 'leukotriene', 'ent_term_norm': 'leukotriene'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '17IQgoEBh99XIFUowxKa', '_score': 9.260006, '_source': {'ent_id': 'Chemical_MESH_D015289', 'ent_term': 'leukotrienes', 'ent_term_norm': 'leukotrienes'}}]
#
#
# #22 acute bronchopulmonary aspergillosis
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'SrEOgoEBh99XIFUocOtH', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D001228', 'ent_term': 'aspergillosis', 'ent_term_norm': 'aspergillosis'}}]
#
#
# #23 steroid|steroids
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '_7ENgoEBh99XIFUoPdZ0', '_score': 17.344439, '_source': {'ent_id': 'Chemical_MESH_D013256', 'ent_term': 'steroid', 'ent_term_norm': 'steroid'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'ALENgoEBh99XIFUoPdeD', '_score': 17.344439, '_source': {'ent_id': 'Chemical_MESH_D013256', 'ent_term': 'steroids', 'ent_term_norm': 'steroids'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'L7ISgoEBh99XIFUozzUc', '_score': 17.344439, '_source': {'ent_id': 'Chemical_MESH_D013256', 'ent_term': 'steroid', 'ent_term_norm': 'steroid'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'MLISgoEBh99XIFUozzUr', '_score': 17.344439, '_source': {'ent_id': 'Chemical_MESH_D013256', 'ent_term': 'steroids', 'ent_term_norm': 'steroids'}}]
#
#
# #24 allergy|allergic|allergic asthma|allergic comorbidity|Omalizumab in Severe Allergic Asthma
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'AbENgoEBh99XIFUoPdeT', '_score': 39.08333, '_source': {'ent_id': 'Disease_MESH_D004342', 'ent_term': 'allergic', 'ent_term_norm': 'allergic'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '-rENgoEBh99XIFUoPdYm', '_score': 19.541664, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'allergic asthma', 'ent_term_norm': 'allergic asthma'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '-bENgoEBh99XIFUoPdYW', '_score': 18.520012, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'asthma', 'ent_term_norm': 'asthma'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'YLITgoEBh99XIFUoLDtU', '_score': 18.520012, '_source': {'ent_id': 'Disease_MESH_D001249', 'ent_term': 'asthma', 'ent_term_norm': 'asthma'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '67ENgoEBh99XIFUoPNY9', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D000069444', 'ent_term': 'omalizumab', 'ent_term_norm': 'omalizumab'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'ArENgoEBh99XIFUoPdej', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D004342', 'ent_term': 'allergy', 'ent_term_norm': 'allergy'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'BLENgoEBh99XIFUoPdfC', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D004342', 'ent_term': 'allergies', 'ent_term_norm': 'allergies'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'abISgoEBh99XIFUo_ziC', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D004342', 'ent_term': 'allergies', 'ent_term_norm': 'allergies'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'X7ITgoEBh99XIFUoLDtF', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D004342', 'ent_term': 'allergy', 'ent_term_norm': 'allergy'}}]
#
#
# #25 cats
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'CbENgoEBh99XIFUoPtcP', '_score': 8.923534, '_source': {'ent_id': 'Species_9685', 'ent_term': 'cats', 'ent_term_norm': 'cats'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'prISgoEBh99XIFUo1jU1', '_score': 8.923534, '_source': {'ent_id': 'Species_9685', 'ent_term': 'cats', 'ent_term_norm': 'cats'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '0bENgoEBh99XIFUo4eHQ', '_score': 8.923534, '_source': {'ent_id': 'Gene_12359', 'ent_term': 'cat', 'ent_term_norm': 'cat'}}]
#
#
# #26 methotrexate
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'B7ENgoEBh99XIFUoPdfw', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D008727', 'ent_term': 'methotrexate', 'ent_term_norm': 'methotrexate'}}]
#
#
# #27 rhinitis
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'CLENgoEBh99XIFUoPdf_', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D012220', 'ent_term': 'rhinitis', 'ent_term_norm': 'rhinitis'}}]
#
#
# #28 SDS
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'C7ENgoEBh99XIFUoPtcu', '_score': 9.260006, '_source': {'ent_id': 'Chemical_MESH_D012967', 'ent_term': 'sds', 'ent_term_norm': 'sds'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'tLISgoEBh99XIFUomTGk', '_score': 9.260006, '_source': {'ent_id': 'Chemical_MESH_D012967', 'ent_term': 'sds', 'ent_term_norm': 'sds'}}]
#
#
# #29 mice
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'CrENgoEBh99XIFUoPtce', '_score': 9.260006, '_source': {'ent_id': 'Species_10090', 'ent_term': 'mice', 'ent_term_norm': 'mice'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '-bISgoEBh99XIFUonTG7', '_score': 9.260006, '_source': {'ent_id': 'Species_10090', 'ent_term': 'mice', 'ent_term_norm': 'mice'}}]
#
#
# #30 thiol|thiols
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'DLENgoEBh99XIFUoPtc-', '_score': 17.344439, '_source': {'ent_id': 'Chemical_MESH_D013438', 'ent_term': 'thiol', 'ent_term_norm': 'thiol'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'DbENgoEBh99XIFUoPtdO', '_score': 17.344439, '_source': {'ent_id': 'Chemical_MESH_D013438', 'ent_term': 'thiols', 'ent_term_norm': 'thiols'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'ObITgoEBh99XIFUoOTwu', '_score': 17.344439, '_source': {'ent_id': 'Chemical_MESH_D013438', 'ent_term': 'thiol', 'ent_term_norm': 'thiol'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'OrITgoEBh99XIFUoOTw-', '_score': 17.344439, '_source': {'ent_id': 'Chemical_MESH_D013438', 'ent_term': 'thiols', 'ent_term_norm': 'thiols'}}]
#
#
# #31 digoxin-disopyramide
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'G7ENgoEBh99XIFUoP9cl', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D004206', 'ent_term': 'disopyramide', 'ent_term_norm': 'disopyramide'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'HrENgoEBh99XIFUoP9db', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D004077', 'ent_term': 'digoxin', 'ent_term_norm': 'digoxin'}}]
#
#
# #32 Foetal tachycardia|tachycardia
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'HbENgoEBh99XIFUoP9dM', '_score': 18.520012, '_source': {'ent_id': 'Disease_MESH_D013610', 'ent_term': 'tachycardia', 'ent_term_norm': 'tachycardia'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'Q7EPgoEBh99XIFUoQ_n0', '_score': 18.520012, '_source': {'ent_id': 'Disease_MESH_D013610', 'ent_term': 'tachycardias', 'ent_term_norm': 'tachycardias'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'HLENgoEBh99XIFUoP9cz', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D013610', 'ent_term': 'foetal tachycardia', 'ent_term_norm': 'foetal tachycardia'}}]
#
#
# #33 patient
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '8bENgoEBh99XIFUoPNaa', '_score': 8.672219, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patient', 'ent_term_norm': 'patient'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '3bENgoEBh99XIFUoO9ZM', '_score': 8.672219, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patients', 'ent_term_norm': 'patients'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '_rISgoEBh99XIFUonjEH', '_score': 8.672219, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patients', 'ent_term_norm': 'patients'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'W7ISgoEBh99XIFUoozKG', '_score': 8.672219, '_source': {'ent_id': 'Species_9606', 'ent_term': 'patient', 'ent_term_norm': 'patient'}}]
#
#
# #34 digoxin
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'HrENgoEBh99XIFUoP9db', '_score': 9.770832, '_source': {'ent_id': 'Chemical_MESH_D004077', 'ent_term': 'digoxin', 'ent_term_norm': 'digoxin'}}]
#
#
# #35 oedema
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'H7ENgoEBh99XIFUoP9dr', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D004487', 'ent_term': 'oedema', 'ent_term_norm': 'oedema'}}]
#
#
# #36 cardiac failure|congestive cardiac failure
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'ILENgoEBh99XIFUoP9d7', '_score': 19.541664, '_source': {'ent_id': 'Disease_MESH_D006333', 'ent_term': 'cardiac failure', 'ent_term_norm': 'cardiac failure'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'JLISgoEBh99XIFUorzPH', '_score': 18.520012, '_source': {'ent_id': 'Disease_MESH_D006333', 'ent_term': 'failure', 'ent_term_norm': 'failure'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'fbEOgoEBh99XIFUoguyR', '_score': 18.520012, '_source': {'ent_id': 'Disease_MESH_D017093', 'ent_term': 'failure', 'ent_term_norm': 'failure'}}]
#
#
# #37 atrial extrasystolic echos
# []
#
#
# #38 chick
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'E7ENgoEBh99XIFUoPteq', '_score': 9.260006, '_source': {'ent_id': 'Species_9031', 'ent_term': 'chick', 'ent_term_norm': 'chick'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'ALITgoEBh99XIFUoJju6', '_score': 9.260006, '_source': {'ent_id': 'Species_9031', 'ent_term': 'chick', 'ent_term_norm': 'chick'}}]
#
#
# #39 guinea-pig
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '7rENgoEBh99XIFUoatkK', '_score': 9.770832, '_source': {'ent_id': 'Species_10141', 'ent_term': 'guinea pig', 'ent_term_norm': 'guinea pig'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '5bISgoEBh99XIFUonDGM', '_score': 8.672219, '_source': {'ent_id': 'Species_9823', 'ent_term': 'pig', 'ent_term_norm': 'pig'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '5rISgoEBh99XIFUonDGb', '_score': 8.672219, '_source': {'ent_id': 'Species_9823', 'ent_term': 'pigs', 'ent_term_norm': 'pigs'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'gLENgoEBh99XIFUo7OIP', '_score': 8.672219, '_source': {'ent_id': 'Species_9823', 'ent_term': 'pig', 'ent_term_norm': 'pig'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'GbEOgoEBh99XIFUoIuYm', '_score': 8.672219, '_source': {'ent_id': 'Species_9823', 'ent_term': 'pigs', 'ent_term_norm': 'pigs'}}]
#
#
# #40 rat
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'FLENgoEBh99XIFUoPte3', '_score': 9.260006, '_source': {'ent_id': 'Species_10116', 'ent_term': 'rat', 'ent_term_norm': 'rat'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '7rISgoEBh99XIFUonTEV', '_score': 9.260006, '_source': {'ent_id': 'Species_10116', 'ent_term': 'rat', 'ent_term_norm': 'rat'}}]
#
#
# #41 contracture
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'F7ENgoEBh99XIFUoPtfn', '_score': 8.923534, '_source': {'ent_id': 'Disease_MESH_D003286', 'ent_term': 'contracture', 'ent_term_norm': 'contracture'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'o7EPgoEBh99XIFUoo_-g', '_score': 8.923534, '_source': {'ent_id': 'Disease_MESH_D003286', 'ent_term': 'contractures', 'ent_term_norm': 'contractures'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '5rITgoEBh99XIFUoBzgV', '_score': 8.923534, '_source': {'ent_id': 'Disease_MESH_D003286', 'ent_term': 'contracture', 'ent_term_norm': 'contracture'}}]
#
#
# #42 toxicity
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'RLENgoEBh99XIFUoX9n0', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D064420', 'ent_term': 'toxicities', 'ent_term_norm': 'toxicities'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'GrENgoEBh99XIFUoP9cV', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D064420', 'ent_term': 'toxicity', 'ent_term_norm': 'toxicity'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'YrISgoEBh99XIFUoozLw', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D064420', 'ent_term': 'toxicity', 'ent_term_norm': 'toxicity'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'Y7ISgoEBh99XIFUoozL-', '_score': 8.672219, '_source': {'ent_id': 'Disease_MESH_D064420', 'ent_term': 'toxicities', 'ent_term_norm': 'toxicities'}}]
#
#
# #43 Melaleuca decreased the tension
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'EbENgoEBh99XIFUoPteM', '_score': 9.770832, '_source': {'ent_id': 'Species_164405', 'ent_term': 'melaleuca', 'ent_term_norm': 'melaleuca'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'ArISgoEBh99XIFUoXy4f', '_score': 9.770832, '_source': {'ent_id': 'Disease_MESH_D002303', 'ent_term': 'decreases', 'ent_term_norm': 'decreases'}}]
#
#
# #44 Salmonella
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '2bEPgoEBh99XIFUoW_rV', '_score': 9.770832, '_source': {'ent_id': 'Species_599', 'ent_term': 'salmonella', 'ent_term_norm': 'salmonella'}}]
#
#
# #45 depression|depressive illness
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'e7EOgoEBh99XIFUoc-tX', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D000275', 'ent_term': 'depressive', 'ent_term_norm': 'depressive'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'S7EOgoEBh99XIFUo-PR0', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D002908', 'ent_term': 'illness', 'ent_term_norm': 'illness'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'wrIPgoEBh99XIFUo8ARR', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D000275', 'ent_term': 'depressing', 'ent_term_norm': 'depressing'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'HbITgoEBh99XIFUoCjlI', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D002908', 'ent_term': 'illness', 'ent_term_norm': 'illness'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'ErENgoEBh99XIFUoXdkc', '_score': 8.923534, '_source': {'ent_id': 'Disease_MESH_D000275', 'ent_term': 'depression', 'ent_term_norm': 'depression'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '07ISgoEBh99XIFUoqjLj', '_score': 8.923534, '_source': {'ent_id': 'Disease_MESH_D000275', 'ent_term': 'depression', 'ent_term_norm': 'depression'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'HLIRgoEBh99XIFUoIhle', '_score': 8.923534, '_source': {'ent_id': 'Disease_MESH_D000275', 'ent_term': 'depressions', 'ent_term_norm': 'depressions'}}]
#
#
# #46 Human|human
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'UrENgoEBh99XIFUoYNnC', '_score': 17.344439, '_source': {'ent_id': 'Species_9606', 'ent_term': 'humans', 'ent_term_norm': 'humans'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'V7ENgoEBh99XIFUoQtfY', '_score': 17.344439, '_source': {'ent_id': 'Species_9606', 'ent_term': 'human', 'ent_term_norm': 'human'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'EbISgoEBh99XIFUonzIo', '_score': 17.344439, '_source': {'ent_id': 'Species_9606', 'ent_term': 'human', 'ent_term_norm': 'human'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': '_bISgoEBh99XIFUonTH4', '_score': 17.344439, '_source': {'ent_id': 'Species_9606', 'ent_term': 'humans', 'ent_term_norm': 'humans'}}]
#
#
# #47 CCR2|Chemokine receptor 2
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': 'abIQgoEBh99XIFUoCQY_', '_score': 9.770832, '_source': {'ent_id': 'Gene_11540', 'ent_term': 'receptor', 'ent_term_norm': 'receptor'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'aLIRgoEBh99XIFUoCRcM', '_score': 9.770832, '_source': {'ent_id': 'Gene_7852', 'ent_term': 'chemokine receptor', 'ent_term_norm': 'chemokine receptor'}}]
#
#
# #48 G-protein coupled receptor|GPCR
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '_7EOgoEBh99XIFUoxvCt', '_score': 9.770832, '_source': {'ent_id': 'Gene_227289', 'ent_term': 'gpcr', 'ent_term_norm': 'gpcr'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'abIQgoEBh99XIFUoCQY_', '_score': 9.770832, '_source': {'ent_id': 'Gene_11540', 'ent_term': 'receptor', 'ent_term_norm': 'receptor'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'K7ENgoEBh99XIFUoQNcs', '_score': 9.260006, '_source': {'ent_id': 'Chemical_MESH_D005998', 'ent_term': 'gly', 'ent_term_norm': 'gly'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'brITgoEBh99XIFUoHjoH', '_score': 9.260006, '_source': {'ent_id': 'Chemical_MESH_D005998', 'ent_term': 'gly', 'ent_term_norm': 'gly'}}]
#
#
# #49 autoimmune diseases
# [{'_index': 'bioconcepts', '_type': '_doc', '_id': '4bEOgoEBh99XIFUoD-Rs', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D001327', 'ent_term': 'autoimmune disease', 'ent_term_norm': 'autoimmune disease'}}, {'_index': 'bioconcepts', '_type': '_doc', '_id': 'H7ISgoEBh99XIFUo7Dc-', '_score': 9.260006, '_source': {'ent_id': 'Disease_MESH_D001327', 'ent_term': 'autoimmune disease', 'ent_term_norm': 'autoimmune disease'}}]

# %% [markdown]
# ---

# %%
from funcs.data_processing.stage1_processing import get_ebi_data

# %%
ebi_data = get_ebi_data(verbose=False)
print(ebi_data.info())
SAMPLE_SIZE = 50
ebi_sample = ebi_data[ebi_data["MAPPING_TYPE"] == "Exact"] \
    [["query", "MAPPED_TERM_LABEL", "MAPPED_TERM_URI"]] \
    .head(SAMPLE_SIZE).drop_duplicates().reset_index(drop=True)
ebi_sample
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1191 entries, 0 to 1190
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   query              1191 non-null   object
#  1   MAPPED_TERM_LABEL  1191 non-null   object
#  2   MAPPED_TERM_URI    1191 non-null   object
#  3   MAPPING_TYPE       1191 non-null   object
#  4   id                 1191 non-null   object
#  5   full_id            1191 non-null   object
#  6   mapping_id         1191 non-null   int64
# dtypes: int64(1), object(6)
# memory usage: 65.3+ KB
# None
#                                                 query  \
# 0                                 alzheimer s disease
# 1                      endocarditis valve unspecified
# 2                  family history of other conditions
# 3                   unspecified maternal hypertension
# 4   stroke not specified as haemorrhage or infarction
# 5                            subarachnoid haemorrhage
# 6            unspecified human immunodeficiency virus
# 7                           other endocrine disorders
# 8                             other diseases of liver
# 9                        primary disorders of muscles
# 10                  pervasive developmental disorders
# 11                     other cerebrovascular diseases
# 12                      other diseases of gallbladder
# 13                fracture of spine level unspecified
# 14                                  acute hepatitis b
# 15                        abnormalities of heart beat
# 16            other congenital malformations of heart
# 17        disorders of tooth development and eruption
# 18                          intracerebral haemorrhage
# 19                     retinal detachments and breaks
# 20                     tuberculosis of nervous system
# 21                                  acute hepatitis a
# 22                                  hookworm diseases
# 23                                    sleep disorders
# 24                        diseases of salivary glands
# 25                          gender identity disorders
# 26                      polyp of female genital tract
# 27                                    persistent mood
# 28                         disorders of vitreous body
# 29                          other coagulation defects
# 30  granulomatous disorders of skin and subcutaneo...
# 31                    excessive vomiting in pregnancy
# 32                   hyperfunction of pituitary gland
# 33                     other nutritional deficiencies
# 34                     other rheumatic heart diseases
# 35                                other helminthiases
# 36                 unspecified viral infection of cns
# 37                  diverticular disease of intestine
# 38                   premature separation of placenta
# 39                                 retention of urine
# 40                   unspecified urinary incontinence
# 41                               isolated proteinuria
# 42                                visual disturbances
# 43                               unspecified dementia
# 44                             unspecified haematuria
# 45                            iron deficiency anaemia
# 46                                acute renal failure
# 47                          nonspecific lymphadenitis
# 48                                    senile cataract
# 49                    reduction defects of lower limb
#
#                                     MAPPED_TERM_LABEL MAPPED_TERM_URI
# 0                                 Alzheimer's disease     EFO_0000249
# 1                                        endocarditis     EFO_0000465
# 2                                      family history     EFO_0000493
# 3                                        preeclampsia     EFO_0000668
# 4                                              stroke     EFO_0000712
# 5                             subarachnoid hemorrhage     EFO_0000713
# 6                                       HIV infection     EFO_0000764
# 7                            endocrine system disease     EFO_0001379
# 8                                       liver disease     EFO_0001421
# 9                                    muscular disease     EFO_0002970
# 10  pervasive developmental disorder - not otherwi...     EFO_0003759
# 11                           cerebrovascular disorder     EFO_0003763
# 12                                gallbladder disease     EFO_0003832
# 13                                   spinal fracture'     EFO_0003902
# 14                              hepatitis B infection     EFO_0004197
# 15                                  cardiac arrythmia     EFO_0004269
# 16                      congenital heart malformation     EFO_0005269
# 17                                     tooth agenesis     EFO_0005410
# 18                           intracerebral hemorrhage     EFO_0005669
# 19                                 retinal detachment     EFO_0005773
# 20                central nervous system tuberculosis     EFO_0007199
# 21                                        hepatitis A     EFO_0007305
# 22                        hookworm infectious disease     EFO_0007314
# 23                                     sleep disorder     EFO_0008568
# 24                             salivary gland disease     EFO_0008581
# 25                           gender identity disorder     EFO_0008587
# 26                         female genital tract polyp     EFO_0008622
# 27                                 dysthymic disorder     EFO_0008623
# 28                              vitreous body disease     EFO_0008624
# 29                          blood coagulation disease     EFO_0009314
# 30                           granulomatous dermatitis     EFO_1000705
# 31                             hyperemesis gravidarum     EFO_1000971
# 32                                   hyperpituitarism     EFO_1000973
# 33                     nutritional deficiency disease     EFO_1001067
# 34                            rheumatic heart disease     EFO_1001161
# 35                                      Helminthiasis     EFO_1001342
# 36                   central nervous system infection     EFO_1001456
# 37                                     diverticulitis     EFO_1001460
# 38                                 Abruptio Placentae     EFO_1001754
# 39                                  Urinary retention      HP_0000016
# 40                               Urinary incontinence      HP_0000020
# 41                                        proteinuria      HP_0000093
# 42                                  Visual impairment      HP_0000505
# 43                                           dementia      HP_0000726
# 44                                          hematuria      HP_0000790
# 45                             Iron deficiency anemia      HP_0001891
# 46                                acute kidney injury      HP_0001919
# 47                                      lymphadenitis      HP_0002840
# 48                               age-related cataract      HP_0011141
# 49                                          Hemimelia   Orphanet_2130

# %%
def search_term(term: str):
    
    search_data = {
        "query": {
            "match": {
                "ent_term_norm": term
            }
        }
    }
    # index_name = INDEX_NAME
    index_name = "bioconcepts"
    url = ES_URL + f"/{index_name}" + "/_search"
    r = requests.get(url, json=search_data)
    r.raise_for_status()
    res = r.json()["hits"]["hits"]
    return res

# %%
for idx, row in ebi_sample.iterrows():
    query = row['query']
    print(f"#{idx} {query}")
    search_res = search_term(term=query)
    pprint(search_res)
    print("\n---\n")
# Out:
# #0 alzheimer s disease
# [{'_id': 'irIYgoEBh99XIFUoE3gL',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': 'alzheimer',
#               'ent_term_norm': 'alzheimer'},
#   '_type': '_doc'},
#  {'_id': 'FrIYgoEBh99XIFUoOHvC',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimer's type dementia",
#               'ent_term_norm': "alzheimer's type dementia"},
#   '_type': '_doc'},
#  {'_id': 'p7IZgoEBh99XIFUoNIv4',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimer's brains",
#               'ent_term_norm': "alzheimer's brains"},
#   '_type': '_doc'},
#  {'_id': 'nrIZgoEBh99XIFUoo5JQ',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimer's dementia",
#               'ent_term_norm': "alzheimer's dementia"},
#   '_type': '_doc'},
#  {'_id': 'zLIZgoEBh99XIFUotJPr',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimer's association",
#               'ent_term_norm': "alzheimer's association"},
#   '_type': '_doc'},
#  {'_id': 'n7IagoEBh99XIFUoI5qQ',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimers' disease",
#               'ent_term_norm': "alzheimers' disease"},
#   '_type': '_doc'},
#  {'_id': 'oLIagoEBh99XIFUoI5qf',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimer's",
#               'ent_term_norm': "alzheimer's"},
#   '_type': '_doc'},
#  {'_id': 'obIagoEBh99XIFUoI5qu',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimer's and dementia",
#               'ent_term_norm': "alzheimer's and dementia"},
#   '_type': '_doc'},
#  {'_id': '07IagoEBh99XIFUotKPN',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimer's pathologies",
#               'ent_term_norm': "alzheimer's pathologies"},
#   '_type': '_doc'},
#  {'_id': '1LIagoEBh99XIFUotKPe',
#   '_index': 'bioconcepts',
#   '_score': 7.263795,
#   '_source': {'ent_id': 'Disease_MESH_D000544',
#               'ent_term': "alzheimer's dement",
#               'ent_term_norm': "alzheimer's dement"},
#   '_type': '_doc'}]
#
# ---
#
# #1 endocarditis valve unspecified
# [{'_id': 'e7IXgoEBh99XIFUoqHGJ',
#   '_index': 'bioconcepts',
#   '_score': 10.029415,
#   '_source': {'ent_id': 'Disease_MESH_D004696',
#               'ent_term': 'endocarditis',
#               'ent_term_norm': 'endocarditis'},
#   '_type': '_doc'},
#  {'_id': 'urMhgoEBh99XIFUoxRqW',
#   '_index': 'bioconcepts',
#   '_score': 10.029415,
#   '_source': {'ent_id': 'Disease_MESH_D004696',
#               'ent_term': 'endocarditis',
#               'ent_term_norm': 'endocarditis'},
#   '_type': '_doc'},
#  {'_id': 'obMngoEBh99XIFUoCHNM',
#   '_index': 'bioconcepts',
#   '_score': 10.029415,
#   '_source': {'ent_id': 'Disease_MESH_D004696',
#               'ent_term': 'endocarditis',
#               'ent_term_norm': 'endocarditis'},
#   '_type': '_doc'},
#  {'_id': 'W7MsgoEBh99XIFUo6Nex',
#   '_index': 'bioconcepts',
#   '_score': 10.029415,
#   '_source': {'ent_id': 'Disease_MESH_D004696',
#               'ent_term': 'endocarditis',
#               'ent_term_norm': 'endocarditis'},
#   '_type': '_doc'},
#  {'_id': 'W7IcgoEBh99XIFUo48gE',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'y7MhgoEBh99XIFUoAA3Y',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'grMmgoEBh99XIFUoQ2aC',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': '7bMsgoEBh99XIFUoaM74',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'T7IWgoEBh99XIFUoiV5p',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'}]
#
# ---
#
# #2 family history of other conditions
# []
#
# ---
#
# #3 unspecified maternal hypertension
# [{'_id': 'JrMlgoEBh99XIFUoSlY5',
#   '_index': 'bioconcepts',
#   '_score': 11.128026,
#   '_source': {'ent_id': 'Gene_126206',
#               'ent_term': 'maternal',
#               'ent_term_norm': 'maternal'},
#   '_type': '_doc'},
#  {'_id': 'WLIcgoEBh99XIFUoELod',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D006973',
#               'ent_term': 'hypertension',
#               'ent_term_norm': 'hypertension'},
#   '_type': '_doc'},
#  {'_id': 'W7IcgoEBh99XIFUo48gE',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'y7MhgoEBh99XIFUoAA3Y',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': '27MhgoEBh99XIFUoAQ3O',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D006973',
#               'ent_term': 'hypertension',
#               'ent_term_norm': 'hypertension'},
#   '_type': '_doc'},
#  {'_id': 'grMmgoEBh99XIFUoQ2aC',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'yrMmgoEBh99XIFUoR2a7',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D006973',
#               'ent_term': 'hypertension',
#               'ent_term_norm': 'hypertension'},
#   '_type': '_doc'},
#  {'_id': '2rMrgoEBh99XIFUoSrtT',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D006973',
#               'ent_term': 'hypertension',
#               'ent_term_norm': 'hypertension'},
#   '_type': '_doc'},
#  {'_id': '7bMsgoEBh99XIFUoaM74',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'xLIWgoEBh99XIFUorWDO',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D006973',
#               'ent_term': 'hypertension',
#               'ent_term_norm': 'hypertension'},
#   '_type': '_doc'}]
#
# ---
#
# #4 stroke not specified as haemorrhage or infarction
# [{'_id': 'tbIfgoEBh99XIFUowPg1',
#   '_index': 'bioconcepts',
#   '_score': 10.617202,
#   '_source': {'ent_id': 'Chemical_MESH_C061189',
#               'ent_term': 'not',
#               'ent_term_norm': 'not'},
#   '_type': '_doc'},
#  {'_id': 'ULMtgoEBh99XIFUojuIu',
#   '_index': 'bioconcepts',
#   '_score': 10.617202,
#   '_source': {'ent_id': 'Gene_208624',
#               'ent_term': 'not',
#               'ent_term_norm': 'not'},
#   '_type': '_doc'},
#  {'_id': 'TrIYgoEBh99XIFUoPHsP',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D007238',
#               'ent_term': 'infarction',
#               'ent_term_norm': 'infarction'},
#   '_type': '_doc'},
#  {'_id': 'iLIbgoEBh99XIFUoEamS',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D007238',
#               'ent_term': 'infarctions',
#               'ent_term_norm': 'infarctions'},
#   '_type': '_doc'},
#  {'_id': 'HrIcgoEBh99XIFUok8OH',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D007238',
#               'ent_term': 'infarction',
#               'ent_term_norm': 'infarction'},
#   '_type': '_doc'},
#  {'_id': 't7IdgoEBh99XIFUoQs4W',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D007238',
#               'ent_term': 'infarctions',
#               'ent_term_norm': 'infarctions'},
#   '_type': '_doc'},
#  {'_id': 'cbMhgoEBh99XIFUo0Bsu',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D007238',
#               'ent_term': 'infarction',
#               'ent_term_norm': 'infarction'},
#   '_type': '_doc'},
#  {'_id': '9bMmgoEBh99XIFUoWWdk',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D007238',
#               'ent_term': 'infarction',
#               'ent_term_norm': 'infarction'},
#   '_type': '_doc'},
#  {'_id': 'mLMsgoEBh99XIFUoVM3p',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D007238',
#               'ent_term': 'infarction',
#               'ent_term_norm': 'infarction'},
#   '_type': '_doc'},
#  {'_id': 'TrMigoEBh99XIFUo7i44',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D007238',
#               'ent_term': 'infarctions',
#               'ent_term_norm': 'infarctions'},
#   '_type': '_doc'}]
#
# ---
#
# #5 subarachnoid haemorrhage
# [{'_id': 'wrIXgoEBh99XIFUoQ2oR',
#   '_index': 'bioconcepts',
#   '_score': 10.029415,
#   '_source': {'ent_id': 'Disease_MESH_D013345',
#               'ent_term': 'subarachnoid haemorrhage',
#               'ent_term_norm': 'subarachnoid haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 's7IdgoEBh99XIFUojNOT',
#   '_index': 'bioconcepts',
#   '_score': 10.029415,
#   '_source': {'ent_id': 'Disease_MESH_D013345',
#               'ent_term': 'subarachnoid haemorrhage',
#               'ent_term_norm': 'subarachnoid haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'prMpgoEBh99XIFUoCZU2',
#   '_index': 'bioconcepts',
#   '_score': 10.029415,
#   '_source': {'ent_id': 'Disease_MESH_D013345',
#               'ent_term': 'subarachnoid haemorrhage',
#               'ent_term_norm': 'subarachnoid haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'r7MsgoEBh99XIFUoGcke',
#   '_index': 'bioconcepts',
#   '_score': 10.029415,
#   '_source': {'ent_id': 'Disease_MESH_D013345',
#               'ent_term': 'subarachnoid haemorrhage',
#               'ent_term_norm': 'subarachnoid haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'QrIcgoEBh99XIFUoWr8Q',
#   '_index': 'bioconcepts',
#   '_score': 9.282201,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'haemorrhage',
#               'ent_term_norm': 'haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'RbIggoEBh99XIFUoIv97',
#   '_index': 'bioconcepts',
#   '_score': 9.282201,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'haemorrhages',
#               'ent_term_norm': 'haemorrhages'},
#   '_type': '_doc'},
#  {'_id': 'irMhgoEBh99XIFUoZxQl',
#   '_index': 'bioconcepts',
#   '_score': 9.282201,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'haemorrhages',
#               'ent_term_norm': 'haemorrhages'},
#   '_type': '_doc'},
#  {'_id': 'KbMhgoEBh99XIFUo-R4_',
#   '_index': 'bioconcepts',
#   '_score': 9.282201,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'haemorrhage',
#               'ent_term_norm': 'haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'rrMogoEBh99XIFUoRYgN',
#   '_index': 'bioconcepts',
#   '_score': 9.282201,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'haemorrhage',
#               'ent_term_norm': 'haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'r7MqgoEBh99XIFUo-rYS',
#   '_index': 'bioconcepts',
#   '_score': 9.282201,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'haemorrhages',
#               'ent_term_norm': 'haemorrhages'},
#   '_type': '_doc'}]
#
# ---
#
# #6 unspecified human immunodeficiency virus
# [{'_id': 'VrIdgoEBh99XIFUoadF9',
#   '_index': 'bioconcepts',
#   '_score': 11.128026,
#   '_source': {'ent_id': 'Species_39420',
#               'ent_term': 'virus',
#               'ent_term_norm': 'virus'},
#   '_type': '_doc'},
#  {'_id': 'W7IcgoEBh99XIFUo48gE',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'y7MhgoEBh99XIFUoAA3Y',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'grMmgoEBh99XIFUoQ2aC',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': '7bMsgoEBh99XIFUoaM74',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'T7IWgoEBh99XIFUoiV5p',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'ALIXgoEBh99XIFUog28u',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D007153',
#               'ent_term': 'immunodeficiency',
#               'ent_term_norm': 'immunodeficiency'},
#   '_type': '_doc'},
#  {'_id': 'o7IdgoEBh99XIFUoBcqc',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D007153',
#               'ent_term': 'immunodeficiency',
#               'ent_term_norm': 'immunodeficiency'},
#   '_type': '_doc'},
#  {'_id': 'xLMigoEBh99XIFUoPyIs',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D007153',
#               'ent_term': 'immunodeficiency',
#               'ent_term_norm': 'immunodeficiency'},
#   '_type': '_doc'},
#  {'_id': 'sLMjgoEBh99XIFUoTzQZ',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D007153',
#               'ent_term': 'immunodeficiencies',
#               'ent_term_norm': 'immunodeficiencies'},
#   '_type': '_doc'}]
#
# ---
#
# #7 other endocrine disorders
# [{'_id': '47IbgoEBh99XIFUoRKyi',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D004700',
#               'ent_term': 'endocrine disorder',
#               'ent_term_norm': 'endocrine disorder'},
#   '_type': '_doc'},
#  {'_id': 'ybIegoEBh99XIFUoFdyO',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D004700',
#               'ent_term': 'endocrine disorder',
#               'ent_term_norm': 'endocrine disorder'},
#   '_type': '_doc'},
#  {'_id': 'HrMtgoEBh99XIFUoP93y',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D004700',
#               'ent_term': 'endocrine disorder',
#               'ent_term_norm': 'endocrine disorder'},
#   '_type': '_doc'},
#  {'_id': 'n7IcgoEBh99XIFUoUL57',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 'urIcgoEBh99XIFUojcKK',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'},
#  {'_id': 'QLMhgoEBh99XIFUoUxPI',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 't7MjgoEBh99XIFUoqjo5',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorder',
#               'ent_term_norm': 'disorder'},
#   '_type': '_doc'},
#  {'_id': 'SbMmgoEBh99XIFUox28T',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': '-rMqgoEBh99XIFUowbLb',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'},
#  {'_id': 'lLMsgoEBh99XIFUocs_q',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'}]
#
# ---
#
# #8 other diseases of liver
# [{'_id': '5rMsgoEBh99XIFUoDchx',
#   '_index': 'bioconcepts',
#   '_score': 11.128026,
#   '_source': {'ent_id': 'Disease_MESH_D017093',
#               'ent_term': 'liver',
#               'ent_term_norm': 'liver'},
#   '_type': '_doc'}]
#
# ---
#
# #9 primary disorders of muscles
# [{'_id': 'j7IbgoEBh99XIFUoAqi8',
#   '_index': 'bioconcepts',
#   '_score': 11.128026,
#   '_source': {'ent_id': 'Disease_MESH_D051270',
#               'ent_term': 'primary disorder',
#               'ent_term_norm': 'primary disorder'},
#   '_type': '_doc'},
#  {'_id': 'zLIZgoEBh99XIFUoSIyF',
#   '_index': 'bioconcepts',
#   '_score': 10.617202,
#   '_source': {'ent_id': 'Disease_MESH_D063806',
#               'ent_term': 'muscle',
#               'ent_term_norm': 'muscle'},
#   '_type': '_doc'},
#  {'_id': 'XbMkgoEBh99XIFUoh0nb',
#   '_index': 'bioconcepts',
#   '_score': 10.617202,
#   '_source': {'ent_id': 'Disease_MESH_D063806',
#               'ent_term': 'muscle',
#               'ent_term_norm': 'muscle'},
#   '_type': '_doc'},
#  {'_id': 'n7IcgoEBh99XIFUoUL57',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 'urIcgoEBh99XIFUojcKK',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'},
#  {'_id': 'QLMhgoEBh99XIFUoUxPI',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 't7MjgoEBh99XIFUoqjo5',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorder',
#               'ent_term_norm': 'disorder'},
#   '_type': '_doc'},
#  {'_id': 'SbMmgoEBh99XIFUox28T',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': '-rMqgoEBh99XIFUowbLb',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'},
#  {'_id': 'lLMsgoEBh99XIFUocs_q',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'}]
#
# ---
#
# #10 pervasive developmental disorders
# [{'_id': 'VrMigoEBh99XIFUoCh_4',
#   '_index': 'bioconcepts',
#   '_score': 11.128026,
#   '_source': {'ent_id': 'Disease_MESH_D002659',
#               'ent_term': 'pervasive developmental',
#               'ent_term_norm': 'pervasive developmental'},
#   '_type': '_doc'},
#  {'_id': 'F7MngoEBh99XIFUoPXcn',
#   '_index': 'bioconcepts',
#   '_score': 11.128026,
#   '_source': {'ent_id': 'Disease_MESH_D002659',
#               'ent_term': 'pervasiveness',
#               'ent_term_norm': 'pervasiveness'},
#   '_type': '_doc'},
#  {'_id': 'E7IagoEBh99XIFUoKpt4',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D002658',
#               'ent_term': 'developmental disorder',
#               'ent_term_norm': 'developmental disorder'},
#   '_type': '_doc'},
#  {'_id': '_LIfgoEBh99XIFUo__zW',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D002658',
#               'ent_term': 'developmental disorder',
#               'ent_term_norm': 'developmental disorder'},
#   '_type': '_doc'},
#  {'_id': 'BrMtgoEBh99XIFUoPt2M',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D002658',
#               'ent_term': 'developmental disorder',
#               'ent_term_norm': 'developmental disorder'},
#   '_type': '_doc'},
#  {'_id': 'n7IcgoEBh99XIFUoUL57',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 'urIcgoEBh99XIFUojcKK',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'},
#  {'_id': 'QLMhgoEBh99XIFUoUxPI',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 't7MjgoEBh99XIFUoqjo5',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorder',
#               'ent_term_norm': 'disorder'},
#   '_type': '_doc'},
#  {'_id': 'SbMmgoEBh99XIFUox28T',
#   '_index': 'bioconcepts',
#   '_score': 9.393426,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'}]
#
# ---
#
# #11 other cerebrovascular diseases
# [{'_id': '87IZgoEBh99XIFUoCogC',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D002561',
#               'ent_term': 'cerebrovascular',
#               'ent_term_norm': 'cerebrovascular'},
#   '_type': '_doc'},
#  {'_id': 'lrIZgoEBh99XIFUosZPG',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D002561',
#               'ent_term': 'cerebrovascular disease',
#               'ent_term_norm': 'cerebrovascular disease'},
#   '_type': '_doc'},
#  {'_id': 'PrIcgoEBh99XIFUoO727',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D002561',
#               'ent_term': 'cerebrovascular',
#               'ent_term_norm': 'cerebrovascular'},
#   '_type': '_doc'},
#  {'_id': 'XbIegoEBh99XIFUoeeN5',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D002561',
#               'ent_term': 'cerebrovascular disease',
#               'ent_term_norm': 'cerebrovascular disease'},
#   '_type': '_doc'},
#  {'_id': 'p7MjgoEBh99XIFUouDtA',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D002561',
#               'ent_term': 'cerebrovascular disease',
#               'ent_term_norm': 'cerebrovascular disease'},
#   '_type': '_doc'},
#  {'_id': '0LMngoEBh99XIFUoGnRx',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D002561',
#               'ent_term': 'cerebrovascular disease',
#               'ent_term_norm': 'cerebrovascular disease'},
#   '_type': '_doc'},
#  {'_id': 'PLMogoEBh99XIFUoPogy',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D002561',
#               'ent_term': 'cerebrovascular',
#               'ent_term_norm': 'cerebrovascular'},
#   '_type': '_doc'},
#  {'_id': 'QbMrgoEBh99XIFUoULwo',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D002561',
#               'ent_term': 'cerebrovascular disease',
#               'ent_term_norm': 'cerebrovascular disease'},
#   '_type': '_doc'}]
#
# ---
#
# #12 other diseases of gallbladder
# []
#
# ---
#
# #13 fracture of spine level unspecified
# [{'_id': 'W7IcgoEBh99XIFUo48gE',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'y7MhgoEBh99XIFUoAA3Y',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'grMmgoEBh99XIFUoQ2aC',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': '7bMsgoEBh99XIFUoaM74',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'T7IWgoEBh99XIFUoiV5p',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'trIbgoEBh99XIFUoUK3Y',
#   '_index': 'bioconcepts',
#   '_score': 8.859344,
#   '_source': {'ent_id': 'Disease_MESH_D050723',
#               'ent_term': 'fractured',
#               'ent_term_norm': 'fractured'},
#   '_type': '_doc'},
#  {'_id': 'FLIcgoEBh99XIFUoDLoz',
#   '_index': 'bioconcepts',
#   '_score': 8.859344,
#   '_source': {'ent_id': 'Disease_MESH_D050723',
#               'ent_term': 'fractures',
#               'ent_term_norm': 'fractures'},
#   '_type': '_doc'},
#  {'_id': 's7IcgoEBh99XIFUoq8Rw',
#   '_index': 'bioconcepts',
#   '_score': 8.859344,
#   '_source': {'ent_id': 'Disease_MESH_D050723',
#               'ent_term': 'fracture',
#               'ent_term_norm': 'fracture'},
#   '_type': '_doc'},
#  {'_id': 'vLIdgoEBh99XIFUonNQP',
#   '_index': 'bioconcepts',
#   '_score': 8.859344,
#   '_source': {'ent_id': 'Disease_MESH_D050723',
#               'ent_term': 'fractured',
#               'ent_term_norm': 'fractured'},
#   '_type': '_doc'},
#  {'_id': 'trMggoEBh99XIFUo_w2Z',
#   '_index': 'bioconcepts',
#   '_score': 8.859344,
#   '_source': {'ent_id': 'Disease_MESH_D050723',
#               'ent_term': 'fractures',
#               'ent_term_norm': 'fractures'},
#   '_type': '_doc'}]
#
# ---
#
# #14 acute hepatitis b
# [{'_id': 'TLMlgoEBh99XIFUo82E_',
#   '_index': 'bioconcepts',
#   '_score': 11.128026,
#   '_source': {'ent_id': 'Gene_10673',
#               'ent_term': 'blys',
#               'ent_term_norm': 'blys'},
#   '_type': '_doc'},
#  {'_id': 'Q7MigoEBh99XIFUoCR_b',
#   '_index': 'bioconcepts',
#   '_score': 10.617202,
#   '_source': {'ent_id': 'Disease_MESH_D017114',
#               'ent_term': 'acute hepatitis',
#               'ent_term_norm': 'acute hepatitis'},
#   '_type': '_doc'},
#  {'_id': 'y7MtgoEBh99XIFUoDdm-',
#   '_index': 'bioconcepts',
#   '_score': 10.617202,
#   '_source': {'ent_id': 'Disease_MESH_D017114',
#               'ent_term': 'acute hepatitis',
#               'ent_term_norm': 'acute hepatitis'},
#   '_type': '_doc'},
#  {'_id': '1LIXgoEBh99XIFUoF2d1',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis',
#               'ent_term_norm': 'hepatitis'},
#   '_type': '_doc'},
#  {'_id': 'urIcgoEBh99XIFUoFbrp',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis',
#               'ent_term_norm': 'hepatitis'},
#   '_type': '_doc'},
#  {'_id': '17IcgoEBh99XIFUoRL2p',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D006509',
#               'ent_term': 'hepatitis b',
#               'ent_term_norm': 'hepatitis b'},
#   '_type': '_doc'},
#  {'_id': 'm7MhgoEBh99XIFUowxrF',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D006509',
#               'ent_term': 'hepatitis b',
#               'ent_term_norm': 'hepatitis b'},
#   '_type': '_doc'},
#  {'_id': '1bMhgoEBh99XIFUoxxoq',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis',
#               'ent_term_norm': 'hepatitis'},
#   '_type': '_doc'},
#  {'_id': 'wbMmgoEBh99XIFUoVmdL',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D006509',
#               'ent_term': 'hepatitis b',
#               'ent_term_norm': 'hepatitis b'},
#   '_type': '_doc'},
#  {'_id': 'm7MmgoEBh99XIFUokGuZ',
#   '_index': 'bioconcepts',
#   '_score': 9.828745,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis',
#               'ent_term_norm': 'hepatitis'},
#   '_type': '_doc'}]
#
# ---
#
# #15 abnormalities of heart beat
# [{'_id': 'vLMkgoEBh99XIFUofkgi',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D018376',
#               'ent_term': 'abnormalities',
#               'ent_term_norm': 'abnormalities'},
#   '_type': '_doc'},
#  {'_id': 'PrMpgoEBh99XIFUo8qUZ',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'abnormalities',
#               'ent_term_norm': 'abnormalities'},
#   '_type': '_doc'},
#  {'_id': 'TLMrgoEBh99XIFUoULzK',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'abnormality',
#               'ent_term_norm': 'abnormality'},
#   '_type': '_doc'}]
#
# ---
#
# #16 other congenital malformations of heart
# [{'_id': '97IYgoEBh99XIFUozYSq',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D000013',
#               'ent_term': 'congenital',
#               'ent_term_norm': 'congenital'},
#   '_type': '_doc'},
#  {'_id': 'SbIZgoEBh99XIFUonpJr',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Gene_435',
#               'ent_term': 'congenital malformation',
#               'ent_term_norm': 'congenital malformation'},
#   '_type': '_doc'},
#  {'_id': 'frMmgoEBh99XIFUocGmE',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D000013',
#               'ent_term': 'congenital malformation',
#               'ent_term_norm': 'congenital malformation'},
#   '_type': '_doc'},
#  {'_id': 'RrMigoEBh99XIFUo7S69',
#   '_index': 'bioconcepts',
#   '_score': 10.280729,
#   '_source': {'ent_id': 'Disease_MESH_D000013',
#               'ent_term': 'congenital malformation',
#               'ent_term_norm': 'congenital malformation'},
#   '_type': '_doc'},
#  {'_id': 'fbIXgoEBh99XIFUo9HZC',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'malformations',
#               'ent_term_norm': 'malformations'},
#   '_type': '_doc'},
#  {'_id': 'hrIdgoEBh99XIFUoP85Q',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'malformations',
#               'ent_term_norm': 'malformations'},
#   '_type': '_doc'},
#  {'_id': 'q7MngoEBh99XIFUo3IGT',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'malformations',
#               'ent_term_norm': 'malformations'},
#   '_type': '_doc'},
#  {'_id': 'arMpgoEBh99XIFUo5aTB',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'malformation',
#               'ent_term_norm': 'malformation'},
#   '_type': '_doc'},
#  {'_id': 'm7MrgoEBh99XIFUo-sdJ',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'malformations',
#               'ent_term_norm': 'malformations'},
#   '_type': '_doc'},
#  {'_id': 'YLMsgoEBh99XIFUo2daL',
#   '_index': 'bioconcepts',
#   '_score': 9.518589,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'malformation',
#               'ent_term_norm': 'malformation'},
#   '_type': '_doc'}]
#
# ---
#
# #17 disorders of tooth development and eruption
# [{'_id': 'Q7MugoEBh99XIFUoJOzH',
#   '_index': 'bioconcepts',
#   '_score': 11.128693,
#   '_source': {'ent_id': 'Chemical_MESH_C019152',
#               'ent_term': 'and',
#               'ent_term_norm': 'and'},
#   '_type': '_doc'},
#  {'_id': 'G7IcgoEBh99XIFUoDLqc',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D003875',
#               'ent_term': 'eruption',
#               'ent_term_norm': 'eruption'},
#   '_type': '_doc'},
#  {'_id': 'NLIcgoEBh99XIFUoO70n',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D003875',
#               'ent_term': 'eruptions',
#               'ent_term_norm': 'eruptions'},
#   '_type': '_doc'},
#  {'_id': '8rMkgoEBh99XIFUoF0FP',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D003875',
#               'ent_term': 'eruptions',
#               'ent_term_norm': 'eruptions'},
#   '_type': '_doc'},
#  {'_id': '7rIWgoEBh99XIFUozmJP',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D003875',
#               'ent_term': 'eruption',
#               'ent_term_norm': 'eruption'},
#   '_type': '_doc'},
#  {'_id': 'n7IcgoEBh99XIFUoUL57',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 'urIcgoEBh99XIFUojcKK',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'},
#  {'_id': 'QLMhgoEBh99XIFUoUxPI',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 't7MjgoEBh99XIFUoqjo5',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorder',
#               'ent_term_norm': 'disorder'},
#   '_type': '_doc'},
#  {'_id': 'SbMmgoEBh99XIFUox28T',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'}]
#
# ---
#
# #18 intracerebral haemorrhage
# [{'_id': 'drIXgoEBh99XIFUo83bW',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D002543',
#               'ent_term': 'intracerebral',
#               'ent_term_norm': 'intracerebral'},
#   '_type': '_doc'},
#  {'_id': 'KrIZgoEBh99XIFUonJKL',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Gene_435',
#               'ent_term': 'intracerebral haemorrhage',
#               'ent_term_norm': 'intracerebral haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'fLIcgoEBh99XIFUo5Mjz',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D002543',
#               'ent_term': 'intracerebral haemorrhage',
#               'ent_term_norm': 'intracerebral haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'MbMhgoEBh99XIFUoNBGA',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'intracerebral haemorrhage',
#               'ent_term_norm': 'intracerebral haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'SLMhgoEBh99XIFUovhrn',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D002543',
#               'ent_term': 'intracerebral',
#               'ent_term_norm': 'intracerebral'},
#   '_type': '_doc'},
#  {'_id': 'bbMmgoEBh99XIFUo9nIH',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D002543',
#               'ent_term': 'intracerebral',
#               'ent_term_norm': 'intracerebral'},
#   '_type': '_doc'},
#  {'_id': 'UbMqgoEBh99XIFUoAqY6',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'intracerebral haemorrhage',
#               'ent_term_norm': 'intracerebral haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'nbMrgoEBh99XIFUoocFv',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D002543',
#               'ent_term': 'intracerebral',
#               'ent_term_norm': 'intracerebral'},
#   '_type': '_doc'},
#  {'_id': 'QrIcgoEBh99XIFUoWr8Q',
#   '_index': 'bioconcepts',
#   '_score': 9.2828665,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'haemorrhage',
#               'ent_term_norm': 'haemorrhage'},
#   '_type': '_doc'},
#  {'_id': 'RbIggoEBh99XIFUoIv97',
#   '_index': 'bioconcepts',
#   '_score': 9.2828665,
#   '_source': {'ent_id': 'Disease_MESH_D006470',
#               'ent_term': 'haemorrhages',
#               'ent_term_norm': 'haemorrhages'},
#   '_type': '_doc'}]
#
# ---
#
# #19 retinal detachments and breaks
# [{'_id': 'Q7MugoEBh99XIFUoJOzH',
#   '_index': 'bioconcepts',
#   '_score': 11.128693,
#   '_source': {'ent_id': 'Chemical_MESH_C019152',
#               'ent_term': 'and',
#               'ent_term_norm': 'and'},
#   '_type': '_doc'},
#  {'_id': '87IXgoEBh99XIFUoznMx',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012163',
#               'ent_term': 'detachment',
#               'ent_term_norm': 'detachment'},
#   '_type': '_doc'},
#  {'_id': '27IdgoEBh99XIFUordUf',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012163',
#               'ent_term': 'detachment',
#               'ent_term_norm': 'detachment'},
#   '_type': '_doc'},
#  {'_id': 'OrMlgoEBh99XIFUoS1Zn',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012163',
#               'ent_term': 'detachment',
#               'ent_term_norm': 'detachment'},
#   '_type': '_doc'},
#  {'_id': 'kbMtgoEBh99XIFUoVd6A',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012163',
#               'ent_term': 'detachment',
#               'ent_term_norm': 'detachment'},
#   '_type': '_doc'},
#  {'_id': '9bIagoEBh99XIFUop6J2',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D012173',
#               'ent_term': 'retinal',
#               'ent_term_norm': 'retinal'},
#   '_type': '_doc'},
#  {'_id': 'AbIcgoEBh99XIFUo7Mnt',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D012163',
#               'ent_term': 'retinal detachment',
#               'ent_term_norm': 'retinal detachment'},
#   '_type': '_doc'},
#  {'_id': 'KrMhgoEBh99XIFUo-R5O',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D012163',
#               'ent_term': 'retinal detachment',
#               'ent_term_norm': 'retinal detachment'},
#   '_type': '_doc'},
#  {'_id': '4bMlgoEBh99XIFUoVVaA',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D012173',
#               'ent_term': 'retinal',
#               'ent_term_norm': 'retinal'},
#   '_type': '_doc'},
#  {'_id': '5bMmgoEBh99XIFUoKmT2',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D012163',
#               'ent_term': 'retinal detachment',
#               'ent_term_norm': 'retinal detachment'},
#   '_type': '_doc'}]
#
# ---
#
# #20 tuberculosis of nervous system
# [{'_id': 'W7IcgoEBh99XIFUoPb1n',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D014376',
#               'ent_term': 'tuberculosis',
#               'ent_term_norm': 'tuberculosis'},
#   '_type': '_doc'},
#  {'_id': 'zLMhgoEBh99XIFUoAA3n',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D014376',
#               'ent_term': 'tuberculosis',
#               'ent_term_norm': 'tuberculosis'},
#   '_type': '_doc'},
#  {'_id': 'vLMmgoEBh99XIFUog2pM',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D014376',
#               'ent_term': 'tuberculosis',
#               'ent_term_norm': 'tuberculosis'},
#   '_type': '_doc'},
#  {'_id': '57MrgoEBh99XIFUopcG1',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D014376',
#               'ent_term': 'tuberculosis',
#               'ent_term_norm': 'tuberculosis'},
#   '_type': '_doc'},
#  {'_id': 'Q7IWgoEBh99XIFUoiF6x',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D014376',
#               'ent_term': 'tuberculosis',
#               'ent_term_norm': 'tuberculosis'},
#   '_type': '_doc'}]
#
# ---
#
# #21 acute hepatitis a
# [{'_id': 'Q7MigoEBh99XIFUoCR_b',
#   '_index': 'bioconcepts',
#   '_score': 10.617867,
#   '_source': {'ent_id': 'Disease_MESH_D017114',
#               'ent_term': 'acute hepatitis',
#               'ent_term_norm': 'acute hepatitis'},
#   '_type': '_doc'},
#  {'_id': 'y7MtgoEBh99XIFUoDdm-',
#   '_index': 'bioconcepts',
#   '_score': 10.617867,
#   '_source': {'ent_id': 'Disease_MESH_D017114',
#               'ent_term': 'acute hepatitis',
#               'ent_term_norm': 'acute hepatitis'},
#   '_type': '_doc'},
#  {'_id': '1LIXgoEBh99XIFUoF2d1',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis',
#               'ent_term_norm': 'hepatitis'},
#   '_type': '_doc'},
#  {'_id': 'uLIYgoEBh99XIFUo94dw',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis a',
#               'ent_term_norm': 'hepatitis a'},
#   '_type': '_doc'},
#  {'_id': 'urIcgoEBh99XIFUoFbrp',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis',
#               'ent_term_norm': 'hepatitis'},
#   '_type': '_doc'},
#  {'_id': '-rIfgoEBh99XIFUo0vng',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis a',
#               'ent_term_norm': 'hepatitis a'},
#   '_type': '_doc'},
#  {'_id': '1bMhgoEBh99XIFUoxxoq',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis',
#               'ent_term_norm': 'hepatitis'},
#   '_type': '_doc'},
#  {'_id': 'cLMkgoEBh99XIFUo1U4b',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis a',
#               'ent_term_norm': 'hepatitis a'},
#   '_type': '_doc'},
#  {'_id': 'm7MmgoEBh99XIFUokGuZ',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis',
#               'ent_term_norm': 'hepatitis'},
#   '_type': '_doc'},
#  {'_id': 'YLMngoEBh99XIFUoMnZu',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D056486',
#               'ent_term': 'hepatitis a',
#               'ent_term_norm': 'hepatitis a'},
#   '_type': '_doc'}]
#
# ---
#
# #22 hookworm diseases
# []
#
# ---
#
# #23 sleep disorders
# [{'_id': 'lrIagoEBh99XIFUoc58e',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012893',
#               'ent_term': 'sleep',
#               'ent_term_norm': 'sleep'},
#   '_type': '_doc'},
#  {'_id': 'KLIagoEBh99XIFUomaLl',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012893',
#               'ent_term': 'sleep disorder',
#               'ent_term_norm': 'sleep disorder'},
#   '_type': '_doc'},
#  {'_id': 'V7IdgoEBh99XIFUoH8wV',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012893',
#               'ent_term': 'sleep',
#               'ent_term_norm': 'sleep'},
#   '_type': '_doc'},
#  {'_id': 'XLIegoEBh99XIFUoS-CV',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012893',
#               'ent_term': 'sleep disorder',
#               'ent_term_norm': 'sleep disorder'},
#   '_type': '_doc'},
#  {'_id': 's7MjgoEBh99XIFUoXjV8',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012893',
#               'ent_term': 'sleep',
#               'ent_term_norm': 'sleep'},
#   '_type': '_doc'},
#  {'_id': '3rMngoEBh99XIFUoZ3k-',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012893',
#               'ent_term': 'sleep disorder',
#               'ent_term_norm': 'sleep disorder'},
#   '_type': '_doc'},
#  {'_id': 'n7MogoEBh99XIFUoJoYf',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012893',
#               'ent_term': 'sleep',
#               'ent_term_norm': 'sleep'},
#   '_type': '_doc'},
#  {'_id': 'YLMigoEBh99XIFUokyjx',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D012893',
#               'ent_term': 'sleep disorder',
#               'ent_term_norm': 'sleep disorder'},
#   '_type': '_doc'},
#  {'_id': 'n7IcgoEBh99XIFUoUL57',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 'urIcgoEBh99XIFUojcKK',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'}]
#
# ---
#
# #24 diseases of salivary glands
# []
#
# ---
#
# #25 gender identity disorders
# [{'_id': 'n7IcgoEBh99XIFUoUL57',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 'urIcgoEBh99XIFUojcKK',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'},
#  {'_id': 'QLMhgoEBh99XIFUoUxPI',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': 't7MjgoEBh99XIFUoqjo5',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorder',
#               'ent_term_norm': 'disorder'},
#   '_type': '_doc'},
#  {'_id': 'SbMmgoEBh99XIFUox28T',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': '-rMqgoEBh99XIFUowbLb',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disorders',
#               'ent_term_norm': 'disorders'},
#   '_type': '_doc'},
#  {'_id': 'lLMsgoEBh99XIFUocs_q',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'},
#  {'_id': '5rIWgoEBh99XIFUor2Dc',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Disease_MESH_D030342',
#               'ent_term': 'disordered',
#               'ent_term_norm': 'disordered'},
#   '_type': '_doc'}]
#
# ---
#
# #26 polyp of female genital tract
# [{'_id': 'ArIYgoEBh99XIFUo7Iei',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
#   '_source': {'ent_id': 'Chemical_MESH_D011122',
#               'ent_term': 'polyp',
#               'ent_term_norm': 'polyp'},
#   '_type': '_doc'},
#  {'_id': 'nrIcgoEBh99XIFUoMrxb',
#   '_index': 'bioconcepts',
#   '_score': 9.394093,
# ...
#               'ent_term_norm': 'urinary incontinence'},
#   '_type': '_doc'},
#  {'_id': 'XLMmgoEBh99XIFUouW42',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D014549',
#               'ent_term': 'incontinence',
#               'ent_term_norm': 'incontinence'},
#   '_type': '_doc'},
#  {'_id': 'SLMrgoEBh99XIFUonMF_',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D014549',
#               'ent_term': 'incontinence',
#               'ent_term_norm': 'incontinence'},
#   '_type': '_doc'}]
#
# ---
#
# #41 isolated proteinuria
# [{'_id': '2bIcgoEBh99XIFUoF7q6',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D011507',
#               'ent_term': 'proteinuria',
#               'ent_term_norm': 'proteinuria'},
#   '_type': '_doc'},
#  {'_id': 'BLMjgoEBh99XIFUovTys',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D011507',
#               'ent_term': 'proteinuria',
#               'ent_term_norm': 'proteinuria'},
#   '_type': '_doc'},
#  {'_id': '5rMngoEBh99XIFUoK3Ub',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D011507',
#               'ent_term': 'proteinuria',
#               'ent_term_norm': 'proteinuria'},
#   '_type': '_doc'},
#  {'_id': '0bMsgoEBh99XIFUo0dUD',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D011507',
#               'ent_term': 'proteinuria',
#               'ent_term_norm': 'proteinuria'},
#   '_type': '_doc'},
#  {'_id': '17IWgoEBh99XIFUozGLz',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D011507',
#               'ent_term': 'proteinuria',
#               'ent_term_norm': 'proteinuria'},
#   '_type': '_doc'}]
#
# ---
#
# #42 visual disturbances
# [{'_id': 'm7IXgoEBh99XIFUo9nYB',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D014786',
#               'ent_term': 'visual',
#               'ent_term_norm': 'visual'},
#   '_type': '_doc'},
#  {'_id': 'w7IagoEBh99XIFUoBZjV',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D010468',
#               'ent_term': 'visual disturbance',
#               'ent_term_norm': 'visual disturbance'},
#   '_type': '_doc'},
#  {'_id': '6LIdgoEBh99XIFUontSu',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D014786',
#               'ent_term': 'visual',
#               'ent_term_norm': 'visual'},
#   '_type': '_doc'},
#  {'_id': 'w7IggoEBh99XIFUoC_3M',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D010468',
#               'ent_term': 'visual disturbance',
#               'ent_term_norm': 'visual disturbance'},
#   '_type': '_doc'},
#  {'_id': 'GLMhgoEBh99XIFUoBQ5r',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D010468',
#               'ent_term': 'visual disturbance',
#               'ent_term_norm': 'visual disturbance'},
#   '_type': '_doc'},
#  {'_id': 'x7MrgoEBh99XIFUoN7qr',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D014786',
#               'ent_term': 'visual',
#               'ent_term_norm': 'visual'},
#   '_type': '_doc'},
#  {'_id': 'srMtgoEBh99XIFUo_enL',
#   '_index': 'bioconcepts',
#   '_score': 10.03008,
#   '_source': {'ent_id': 'Disease_MESH_D010468',
#               'ent_term': 'visual disturbance',
#               'ent_term_norm': 'visual disturbance'},
#   '_type': '_doc'}]
#
# ---
#
# #43 unspecified dementia
# [{'_id': 'W7IcgoEBh99XIFUo48gE',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'y7MhgoEBh99XIFUoAA3Y',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'grMmgoEBh99XIFUoQ2aC',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': '7bMsgoEBh99XIFUoaM74',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'T7IWgoEBh99XIFUoiV5p',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'JLIXgoEBh99XIFUoHGgR',
#   '_index': 'bioconcepts',
#   '_score': 9.2828665,
#   '_source': {'ent_id': 'Disease_MESH_D003704',
#               'ent_term': 'dementias',
#               'ent_term_norm': 'dementias'},
#   '_type': '_doc'},
#  {'_id': 'i7IcgoEBh99XIFUoE7om',
#   '_index': 'bioconcepts',
#   '_score': 9.2828665,
#   '_source': {'ent_id': 'Disease_MESH_D003704',
#               'ent_term': 'dementia',
#               'ent_term_norm': 'dementia'},
#   '_type': '_doc'},
#  {'_id': 'aLIcgoEBh99XIFUo48jK',
#   '_index': 'bioconcepts',
#   '_score': 9.2828665,
#   '_source': {'ent_id': 'Disease_MESH_D003704',
#               'ent_term': 'dementias',
#               'ent_term_norm': 'dementias'},
#   '_type': '_doc'},
#  {'_id': 'u7MggoEBh99XIFUo_w3l',
#   '_index': 'bioconcepts',
#   '_score': 9.2828665,
#   '_source': {'ent_id': 'Disease_MESH_D003704',
#               'ent_term': 'dementia',
#               'ent_term_norm': 'dementia'},
#   '_type': '_doc'},
#  {'_id': '8bMlgoEBh99XIFUoZVcm',
#   '_index': 'bioconcepts',
#   '_score': 9.2828665,
#   '_source': {'ent_id': 'Disease_MESH_D003704',
#               'ent_term': 'dementias',
#               'ent_term_norm': 'dementias'},
#   '_type': '_doc'}]
#
# ---
#
# #44 unspecified haematuria
# [{'_id': 'qrIZgoEBh99XIFUoBYi-',
#   '_index': 'bioconcepts',
#   '_score': 10.281396,
#   '_source': {'ent_id': 'Disease_MESH_D006417',
#               'ent_term': 'haematuria',
#               'ent_term_norm': 'haematuria'},
#   '_type': '_doc'},
#  {'_id': 'vLMlgoEBh99XIFUoYlcN',
#   '_index': 'bioconcepts',
#   '_score': 10.281396,
#   '_source': {'ent_id': 'Disease_MESH_D006417',
#               'ent_term': 'haematuria',
#               'ent_term_norm': 'haematuria'},
#   '_type': '_doc'},
#  {'_id': '87MrgoEBh99XIFUoDbc8',
#   '_index': 'bioconcepts',
#   '_score': 10.281396,
#   '_source': {'ent_id': 'Disease_MESH_D006417',
#               'ent_term': 'haematuria',
#               'ent_term_norm': 'haematuria'},
#   '_type': '_doc'},
#  {'_id': 'W7IcgoEBh99XIFUo48gE',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'y7MhgoEBh99XIFUoAA3Y',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'grMmgoEBh99XIFUoQ2aC',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': '7bMsgoEBh99XIFUoaM74',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'},
#  {'_id': 'T7IWgoEBh99XIFUoiV5p',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Species_32644',
#               'ent_term': 'unspecified',
#               'ent_term_norm': 'unspecified'},
#   '_type': '_doc'}]
#
# ---
#
# #45 iron deficiency anaemia
# [{'_id': 'frIYgoEBh99XIFUoA3ds',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_C562385',
#               'ent_term': 'iron deficiency',
#               'ent_term_norm': 'iron deficiency'},
#   '_type': '_doc'},
#  {'_id': 'srIcgoEBh99XIFUoFbpy',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D007153',
#               'ent_term': 'deficiency',
#               'ent_term_norm': 'deficiency'},
#   '_type': '_doc'},
#  {'_id': '77IcgoEBh99XIFUoZL8N',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Chemical_MESH_D007501',
#               'ent_term': 'iron',
#               'ent_term_norm': 'iron'},
#   '_type': '_doc'},
#  {'_id': '1bIcgoEBh99XIFUoj8Il',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_C562385',
#               'ent_term': 'iron deficiency',
#               'ent_term_norm': 'iron deficiency'},
#   '_type': '_doc'},
#  {'_id': '4LMhgoEBh99XIFUoAg0b',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Chemical_MESH_D007501',
#               'ent_term': 'iron',
#               'ent_term_norm': 'iron'},
#   '_type': '_doc'},
#  {'_id': 'Q7MhgoEBh99XIFUorxl1',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_C562385',
#               'ent_term': 'iron deficiency',
#               'ent_term_norm': 'iron deficiency'},
#   '_type': '_doc'},
#  {'_id': 'S7MhgoEBh99XIFUozhsN',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D007153',
#               'ent_term': 'deficiency',
#               'ent_term_norm': 'deficiency'},
#   '_type': '_doc'},
#  {'_id': 'm7MmgoEBh99XIFUoVGcI',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D007153',
#               'ent_term': 'deficiency',
#               'ent_term_norm': 'deficiency'},
#   '_type': '_doc'},
#  {'_id': 'XrMmgoEBh99XIFUoyG9O',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Chemical_MESH_D007501',
#               'ent_term': 'iron',
#               'ent_term_norm': 'iron'},
#   '_type': '_doc'},
#  {'_id': 'aLMpgoEBh99XIFUoi55M',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_C562385',
#               'ent_term': 'iron deficiency',
#               'ent_term_norm': 'iron deficiency'},
#   '_type': '_doc'}]
#
# ---
#
# #46 acute renal failure
# [{'_id': 'E7IXgoEBh99XIFUoKWnp',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D051437',
#               'ent_term': 'renal failure',
#               'ent_term_norm': 'renal failure'},
#   '_type': '_doc'},
#  {'_id': 'PLIXgoEBh99XIFUow3M6',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D017093',
#               'ent_term': 'failure',
#               'ent_term_norm': 'failure'},
#   '_type': '_doc'},
#  {'_id': '47IcgoEBh99XIFUoCblW',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D006333',
#               'ent_term': 'failure',
#               'ent_term_norm': 'failure'},
#   '_type': '_doc'},
#  {'_id': 'TbIcgoEBh99XIFUoWr-6',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D051437',
#               'ent_term': 'renal failure',
#               'ent_term_norm': 'renal failure'},
#   '_type': '_doc'},
#  {'_id': 'VLMhgoEBh99XIFUooRgD',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D017093',
#               'ent_term': 'failure',
#               'ent_term_norm': 'failure'},
#   '_type': '_doc'},
#  {'_id': '57MhgoEBh99XIFUo9R1U',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D051437',
#               'ent_term': 'renal failure',
#               'ent_term_norm': 'renal failure'},
#   '_type': '_doc'},
#  {'_id': 'X7MmgoEBh99XIFUoX2jF',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D051437',
#               'ent_term': 'renal failure',
#               'ent_term_norm': 'renal failure'},
#   '_type': '_doc'},
#  {'_id': 'wbMmgoEBh99XIFUog2qY',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D017093',
#               'ent_term': 'failure',
#               'ent_term_norm': 'failure'},
#   '_type': '_doc'},
#  {'_id': 'CLMrgoEBh99XIFUoTLzo',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D006333',
#               'ent_term': 'failure',
#               'ent_term_norm': 'failure'},
#   '_type': '_doc'},
#  {'_id': 'q7MrgoEBh99XIFUok8A0',
#   '_index': 'bioconcepts',
#   '_score': 9.829411,
#   '_source': {'ent_id': 'Disease_MESH_D051437',
#               'ent_term': 'renal failure',
#               'ent_term_norm': 'renal failure'},
#   '_type': '_doc'}]
#
# ---
#
# #47 nonspecific lymphadenitis
# [{'_id': 'FrIagoEBh99XIFUoG5oC',
#   '_index': 'bioconcepts',
#   '_score': 10.617867,
#   '_source': {'ent_id': 'Disease_MESH_D008199',
#               'ent_term': 'lymphadenitis',
#               'ent_term_norm': 'lymphadenitis'},
#   '_type': '_doc'},
#  {'_id': 'n7MsgoEBh99XIFUo7Ne2',
#   '_index': 'bioconcepts',
#   '_score': 10.617867,
#   '_source': {'ent_id': 'Disease_MESH_D008199',
#               'ent_term': 'lymphadenitis',
#               'ent_term_norm': 'lymphadenitis'},
#   '_type': '_doc'}]
#
# ---
#
# #48 senile cataract
# [{'_id': 'ybMggoEBh99XIFUosghK',
#   '_index': 'bioconcepts',
#   '_score': 10.281396,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'senile cataract',
#               'ent_term_norm': 'senile cataract'},
#   '_type': '_doc'},
#  {'_id': 'ZbMngoEBh99XIFUo54K2',
#   '_index': 'bioconcepts',
#   '_score': 10.281396,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'senile cataract',
#               'ent_term_norm': 'senile cataract'},
#   '_type': '_doc'},
#  {'_id': 'srMugoEBh99XIFUoHOsP',
#   '_index': 'bioconcepts',
#   '_score': 10.281396,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'senile cataract',
#               'ent_term_norm': 'senile cataract'},
#   '_type': '_doc'},
#  {'_id': 'NbIWgoEBh99XIFUo8GVA',
#   '_index': 'bioconcepts',
#   '_score': 9.182783,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'cataracts',
#               'ent_term_norm': 'cataracts'},
#   '_type': '_doc'},
#  {'_id': 'gbIcgoEBh99XIFUo5chB',
#   '_index': 'bioconcepts',
#   '_score': 9.182783,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'cataracts',
#               'ent_term_norm': 'cataracts'},
#   '_type': '_doc'},
#  {'_id': 'grIcgoEBh99XIFUo5chR',
#   '_index': 'bioconcepts',
#   '_score': 9.182783,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'cataract',
#               'ent_term_norm': 'cataract'},
#   '_type': '_doc'},
#  {'_id': 'JLMhgoEBh99XIFUo-B7x',
#   '_index': 'bioconcepts',
#   '_score': 9.182783,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'cataract',
#               'ent_term_norm': 'cataract'},
#   '_type': '_doc'},
#  {'_id': '2LMigoEBh99XIFUoMSEL',
#   '_index': 'bioconcepts',
#   '_score': 9.182783,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'cataracts',
#               'ent_term_norm': 'cataracts'},
#   '_type': '_doc'},
#  {'_id': 'LLMngoEBh99XIFUoEHSn',
#   '_index': 'bioconcepts',
#   '_score': 9.182783,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'cataracts',
#               'ent_term_norm': 'cataracts'},
#   '_type': '_doc'},
#  {'_id': 'LbMngoEBh99XIFUoEHS2',
#   '_index': 'bioconcepts',
#   '_score': 9.182783,
#   '_source': {'ent_id': 'Disease_MESH_D002386',
#               'ent_term': 'cataract',
#               'ent_term_norm': 'cataract'},
#   '_type': '_doc'}]
#
# ---
#
# #49 reduction defects of lower limb
# [{'_id': 'trMpgoEBh99XIFUo26Nm',
#   '_index': 'bioconcepts',
#   '_score': 11.128693,
#   '_source': {'ent_id': 'Disease_MESH_D000014',
#               'ent_term': 'defect',
#               'ent_term_norm': 'defect'},
#   '_type': '_doc'},
#  {'_id': '7rMrgoEBh99XIFUo0sSA',
#   '_index': 'bioconcepts',
#   '_score': 11.128693,
#   '_source': {'ent_id': 'Disease_MESH_D007022',
#               'ent_term': 'reduction',
#               'ent_term_norm': 'reduction'},
#   '_type': '_doc'}]
#
# ---

# %% [markdown]
# ---

# %%
def search_term(term: str):
    exclude_terms = ["and", "ands", "not", "with", "other"]
    search_data = {
        "query": {
            "bool": {
                "should": {
                     "match": {
                        "ent_term_norm": term
                    }       
                },
                "must_not": [{"term": {"ent_term_norm": _}} for _ in exclude_terms]
            }
        },
        "aggs": {
            "dedup": {
                "terms": {
                    "field": "ent_id"
                },
                "aggs": {
                    "dedup_docs": {
                        "top_hits": {
                            "size": 1
                        }
                    }
                }
            }
        }
    }
    index_name = "bioconcepts"
    url = ES_URL + f"/{index_name}" + "/_search"
    r = requests.get(url, json=search_data)
    r.raise_for_status()
    # res = r.json()["hits"]["hits"]
    res = r.json()
    return res

# %%
terms = [
    "gonarthrosis",
    "psoriatic and enteropathic arthropathies",
    "pain associated with micturition",
    "other mood",
    "preterm delivery",
    "injury of nerves at forearm level",
    "injury of nerves at wrist and hand level",
    "gastritis and duodenitis",
    "problems related to physical environment",
]
for idx, _ in enumerate(terms):
    search_res = search_term(_)
    print(f"#{idx} {_}")
    pprint(search_res)
    print("\n---\n")
# Out:
# #0 gonarthrosis
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 0}},
#  'hits': {'hits': [],
#           'max_score': None,
#           'total': {'relation': 'eq', 'value': 0}},
#  'timed_out': False,
#  'took': 397}
#
# ---
#
# #1 psoriatic and enteropathic arthropathies
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [{'dedup_docs': {'hits': {'hits': [{'_id': 'JbIYgoEBh99XIFUowYQ6',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.000624,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D007592',
#                                                                                        'ent_term': 'arthropathy',
#                                                                                        'ent_term_norm': 'arthropathy'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.000624,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 193}}},
#                                          'doc_count': 193,
#                                          'key': 'Disease_MESH_D007592'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'XrIegoEBh99XIFUoauJ4',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.975562,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D015535',
#                                                                                        'ent_term': 'psoriatic',
#                                                                                        'ent_term_norm': 'psoriatic'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.975562,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 74}}},
#                                          'doc_count': 74,
#                                          'key': 'Disease_MESH_D015535'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'gcU2g4EBh99XIFUoSmn7',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.000624,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D004213',
#                                                                                        'ent_term': 'arthropathies',
#                                                                                        'ent_term_norm': 'arthropathies'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.000624,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 2}}},
#                                          'doc_count': 2,
#                                          'key': 'Disease_MESH_D004213'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'R_C9hYEBh99XIFUorUQ8',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.000624,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D018771',
#                                                                                        'ent_term': "arthropathy'arthralgia",
#                                                                                        'ent_term_norm': "arthropathy'arthralgia"},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.000624,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D018771'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': '6eQQhYEBh99XIFUoUsXu',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.000624,
#                                                                            '_source': {'ent_id': 'Gene_827783',
#                                                                                        'ent_term': 'arthropathy',
#                                                                                        'ent_term_norm': 'arthropathy'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.000624,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Gene_827783'}],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'XrIegoEBh99XIFUoauJ4',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': 'ofPnhYEBh99XIFUodwrM',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': '6O-xhYEBh99XIFUoonfO',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': 'NLQ9goEBh99XIFUoae89',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': 'krVDgoEBh99XIFUo8F1v',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': 'DrZTgoEBh99XIFUot2ne',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': '8bhvgoEBh99XIFUogj45',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': 'BbmFgoEBh99XIFUoj7R7',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': 'VbmJgoEBh99XIFUoSvNN',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'},
#                    {'_id': 'H7qRgoEBh99XIFUo8obF',
#                     '_index': 'bioconcepts',
#                     '_score': 10.975562,
#                     '_source': {'ent_id': 'Disease_MESH_D015535',
#                                 'ent_term': 'psoriatic',
#                                 'ent_term_norm': 'psoriatic'},
#                     '_type': '_doc'}],
#           'max_score': 10.975562,
#           'total': {'relation': 'eq', 'value': 271}},
#  'timed_out': False,
#  'took': 19}
#
# ---
#
# #2 pain associated with micturition
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [{'dedup_docs': {'hits': {'hits': [{'_id': 'DrIcgoEBh99XIFUoC7rZ',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.000624,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D010146',
#                                                                                        'ent_term': 'pain',
#                                                                                        'ent_term_norm': 'pain'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.000624,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 196}}},
#                                          'doc_count': 196,
#                                          'key': 'Disease_MESH_D010146'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'BbIXgoEBh99XIFUog293',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.6467905,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                                                                        'ent_term': 'associated',
#                                                                                        'ent_term_norm': 'associated'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.6467905,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 101}}},
#                                          'doc_count': 101,
#                                          'key': 'Disease_MESH_D000072716'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'N8qHg4EBh99XIFUoxs1Y',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.6467905,
#                                                                            '_source': {'ent_id': 'Chemical_-',
#                                                                                        'ent_term': 'associated',
#                                                                                        'ent_term_norm': 'associated'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.6467905,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 2}}},
#                                          'doc_count': 2,
#                                          'key': 'Chemical_-'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'tOc2hYEBh99XIFUoEEYt',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.000624,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D000699',
#                                                                                        'ent_term': 'pain',
#                                                                                        'ent_term_norm': 'pain'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.000624,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D000699'}],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'BbIXgoEBh99XIFUog293',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': '7rMngoEBh99XIFUo4IGC',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': 'zbMtgoEBh99XIFUo8OhG',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': 'iLVJgoEBh99XIFUo9MMr',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': 'gLVNgoEBh99XIFUoFfgP',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': 'NbZYgoEBh99XIFUo3sCN',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': '0rdhgoEBh99XIFUol1Mf',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': 'drdqgoEBh99XIFUoROYB',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': 'VbhygoEBh99XIFUoYG-T',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'},
#                    {'_id': '5Lh6goEBh99XIFUoHvFb',
#                     '_index': 'bioconcepts',
#                     '_score': 10.6467905,
#                     '_source': {'ent_id': 'Disease_MESH_D000072716',
#                                 'ent_term': 'associated',
#                                 'ent_term_norm': 'associated'},
#                     '_type': '_doc'}],
#           'max_score': 10.6467905,
#           'total': {'relation': 'eq', 'value': 300}},
#  'timed_out': False,
#  'took': 13}
#
# ---
#
# #3 other mood
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [{'dedup_docs': {'hits': {'hits': [{'_id': 'PLMkgoEBh99XIFUoOUSH',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.468649,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D019964',
#                                                                                        'ent_term': 'mood',
#                                                                                        'ent_term_norm': 'mood'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.468649,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 44}}},
#                                          'doc_count': 44,
#                                          'key': 'Disease_MESH_D019964'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': '0e2WhYEBh99XIFUoNaWf',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.468649,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D006331',
#                                                                                        'ent_term': 'mood',
#                                                                                        'ent_term_norm': 'mood'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.468649,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D006331'}],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'PLMkgoEBh99XIFUoOUSH',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': '7bMugoEBh99XIFUo8vm7',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': 'VbQ1goEBh99XIFUoKGNN',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': 'QrZYgoEBh99XIFUo38BS',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': '9LdjgoEBh99XIFUo93tZ',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': 'nLh5goEBh99XIFUoNuIi',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': 'jruggoEBh99XIFUoiH3F',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': 'K725goEBh99XIFUoUiLg',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': '973CgoEBh99XIFUo0sIf',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'},
#                    {'_id': 'ob_ggoEBh99XIFUo8MGh',
#                     '_index': 'bioconcepts',
#                     '_score': 11.468649,
#                     '_source': {'ent_id': 'Disease_MESH_D019964',
#                                 'ent_term': 'mood',
#                                 'ent_term_norm': 'mood'},
#                     '_type': '_doc'}],
#           'max_score': 11.468649,
#           'total': {'relation': 'eq', 'value': 45}},
#  'timed_out': False,
#  'took': 9}
#
# ---
#
# #4 preterm delivery
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 0}},
#  'hits': {'hits': [],
#           'max_score': None,
#           'total': {'relation': 'eq', 'value': 0}},
#  'timed_out': False,
#  'took': 6}
#
# ---
#
# #5 injury of nerves at forearm level
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [{'dedup_docs': {'hits': {'hits': [{'_id': 'M7IXgoEBh99XIFUoaG0a',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 9.316377,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D014947',
#                                                                                        'ent_term': 'injury',
#                                                                                        'ent_term_norm': 'injury'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 9.316377,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 197}}},
#                                          'doc_count': 197,
#                                          'key': 'Disease_MESH_D014947'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': '8bIcgoEBh99XIFUoJ7vw',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 9.316377,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D058186',
#                                                                                        'ent_term': 'injury',
#                                                                                        'ent_term_norm': 'injury'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 9.316377,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 192}}},
#                                          'doc_count': 192,
#                                          'key': 'Disease_MESH_D058186'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'A-t2hYEBh99XIFUo2pKs',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 9.316377,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D005547',
#                                                                                        'ent_term': 'injuries',
#                                                                                        'ent_term_norm': 'injuries'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 9.316377,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D005547'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'O8H-goEBh99XIFUozL39',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 9.316377,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D018352',
#                                                                                        'ent_term': "injury's "
#                                                                                                    'middle',
#                                                                                        'ent_term_norm': "injury's "
#                                                                                                         'middle'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 9.316377,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D018352'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'Ts2yg4EBh99XIFUoo6IO',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 14.8808975,
#                                                                            '_source': {'ent_id': 'Gene_818706',
#                                                                                        'ent_term': 'level',
#                                                                                        'ent_term_norm': 'level'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 14.8808975,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Gene_818706'}],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'Ts2yg4EBh99XIFUoo6IO',
#                     '_index': 'bioconcepts',
#                     '_score': 14.8808975,
#                     '_source': {'ent_id': 'Gene_818706',
#                                 'ent_term': 'level',
#                                 'ent_term_norm': 'level'},
#                     '_type': '_doc'},
#                    {'_id': 'M7IXgoEBh99XIFUoaG0a',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D014947',
#                                 'ent_term': 'injury',
#                                 'ent_term_norm': 'injury'},
#                     '_type': '_doc'},
#                    {'_id': '8bIcgoEBh99XIFUoJ7vw',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D058186',
#                                 'ent_term': 'injury',
#                                 'ent_term_norm': 'injury'},
#                     '_type': '_doc'},
#                    {'_id': 'Z7IdgoEBh99XIFUoEcsQ',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D014947',
#                                 'ent_term': 'injuries',
#                                 'ent_term_norm': 'injuries'},
#                     '_type': '_doc'},
#                    {'_id': 'GbMhgoEBh99XIFUoMxEX',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D058186',
#                                 'ent_term': 'injury',
#                                 'ent_term_norm': 'injury'},
#                     '_type': '_doc'},
#                    {'_id': 'vrMmgoEBh99XIFUokmub',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D058186',
#                                 'ent_term': 'injury',
#                                 'ent_term_norm': 'injury'},
#                     '_type': '_doc'},
#                    {'_id': 'FrMmgoEBh99XIFUotW4_',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D058186',
#                                 'ent_term': 'injuries',
#                                 'ent_term_norm': 'injuries'},
#                     '_type': '_doc'},
#                    {'_id': 'prMrgoEBh99XIFUoVrwY',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D014947',
#                                 'ent_term': 'injury',
#                                 'ent_term_norm': 'injury'},
#                     '_type': '_doc'},
#                    {'_id': '87MtgoEBh99XIFUop-MJ',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D014947',
#                                 'ent_term': 'injuries',
#                                 'ent_term_norm': 'injuries'},
#                     '_type': '_doc'},
#                    {'_id': 'wbIWgoEBh99XIFUokF5G',
#                     '_index': 'bioconcepts',
#                     '_score': 9.316377,
#                     '_source': {'ent_id': 'Disease_MESH_D058186',
#                                 'ent_term': 'injuries',
#                                 'ent_term_norm': 'injuries'},
#                     '_type': '_doc'}],
#           'max_score': 14.8808975,
#           'total': {'relation': 'eq', 'value': 392}},
#  'timed_out': False,
#  'took': 13}
#
# ---
#
# #6 injury of nerves at wrist and hand level
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [{'dedup_docs': {'hits': {'hits': [{'_id': 'M7IXgoEBh99XIFUoaG0a',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 9.316377,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D014947',
#                                                                                        'ent_term': 'injury',
#                                                                                        'ent_term_norm': 'injury'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 9.316377,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 197}}},
#                                          'doc_count': 197,
#                                          'key': 'Disease_MESH_D014947'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': '8bIcgoEBh99XIFUoJ7vw',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 9.316377,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D058186',
#                                                                                        'ent_term': 'injury',
#                                                                                        'ent_term_norm': 'injury'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 9.316377,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 192}}},
#                                          'doc_count': 192,
#                                          'key': 'Disease_MESH_D058186'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'VrMrgoEBh99XIFUo58Yl',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.44691,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D020943',
#                                                                                        'ent_term': 'hand',
#                                                                                        'ent_term_norm': 'hand'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.44691,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 14}}},
#                                          'doc_count': 14,
#                                          'key': 'Disease_MESH_D020943'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'BbypgoEBh99XIFUoGA8P',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.44691,
#                                                                            '_source': {'ent_id': 'Gene_34379',
#                                                                                        'ent_term': 'hand',
#                                                                                        'ent_term_norm': 'hand'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.44691,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 12}}},
#                                          'doc_count': 12,
#                                          'key': 'Gene_34379'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': '8bZTgoEBh99XIFUoxGn6',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.44691,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D006230',
#                                                                                        'ent_term': 'handness',
#                                                                                        'ent_term_norm': 'handness'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.44691,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 7}}},
#                                          'doc_count': 7,
#                                          'key': 'Disease_MESH_D006230'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'GbQ9goEBh99XIFUoOuzg',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.44691,
#                                                                            '_source': {'ent_id': 'Disease_MESH_C574275',
#                                                                                        'ent_term': 'hand',
#                                                                                        'ent_term_norm': 'hand'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.44691,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 6}}},
#                                          'doc_count': 6,
#                                          'key': 'Disease_MESH_C574275'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': '8bywgoEBh99XIFUog4ye',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.44691,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D019965',
#                                                                                        'ent_term': 'hand',
#                                                                                        'ent_term_norm': 'hand'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.44691,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 3}}},
#                                          'doc_count': 3,
#                                          'key': 'Disease_MESH_D019965'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'A-t2hYEBh99XIFUo2pKs',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 9.316377,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D005547',
#                                                                                        'ent_term': 'injuries',
#                                                                                        'ent_term_norm': 'injuries'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 9.316377,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D005547'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'ws7Ag4EBh99XIFUoYorH',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.44691,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D005597',
#                                                                                        'ent_term': "hand's "
#                                                                                                    'opening',
#                                                                                        'ent_term_norm': "hand's "
#                                                                                                         'opening'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.44691,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D005597'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'CdDgg4EBh99XIFUoH6O0',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.44691,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D009422',
#                                                                                        'ent_term': 'hand',
#                                                                                        'ent_term_norm': 'hand'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.44691,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D009422'}],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 4}},
#  'hits': {'hits': [{'_id': 'Ts2yg4EBh99XIFUoo6IO',
#                     '_index': 'bioconcepts',
#                     '_score': 14.8808975,
#                     '_source': {'ent_id': 'Gene_818706',
#                                 'ent_term': 'level',
#                                 'ent_term_norm': 'level'},
#                     '_type': '_doc'},
#                    {'_id': 'VrMrgoEBh99XIFUo58Yl',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Disease_MESH_D020943',
#                                 'ent_term': 'hand',
#                                 'ent_term_norm': 'hand'},
#                     '_type': '_doc'},
#                    {'_id': 'XbQ3goEBh99XIFUo0ZDz',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Disease_MESH_D020943',
#                                 'ent_term': 'hand',
#                                 'ent_term_norm': 'hand'},
#                     '_type': '_doc'},
#                    {'_id': 'GbQ9goEBh99XIFUoOuzg',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Disease_MESH_C574275',
#                                 'ent_term': 'hand',
#                                 'ent_term_norm': 'hand'},
#                     '_type': '_doc'},
#                    {'_id': '8bZTgoEBh99XIFUoxGn6',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Disease_MESH_D006230',
#                                 'ent_term': 'handness',
#                                 'ent_term_norm': 'handness'},
#                     '_type': '_doc'},
#                    {'_id': 'KbdhgoEBh99XIFUojFPU',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Gene_None',
#                                 'ent_term': 'hand',
#                                 'ent_term_norm': 'hand'},
#                     '_type': '_doc'},
#                    {'_id': 'HbdkgoEBh99XIFUo0YoD',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Disease_MESH_C574275',
#                                 'ent_term': 'hand',
#                                 'ent_term_norm': 'hand'},
#                     '_type': '_doc'},
#                    {'_id': 'QrdmgoEBh99XIFUoH6Af',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Disease_MESH_D020943',
#                                 'ent_term': 'hands',
#                                 'ent_term_norm': 'hands'},
#                     '_type': '_doc'},
#                    {'_id': '5LhugoEBh99XIFUoUCoZ',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Disease_MESH_D020943',
#                                 'ent_term': 'hand',
#                                 'ent_term_norm': 'hand'},
#                     '_type': '_doc'},
#                    {'_id': 'qLh1goEBh99XIFUot6cF',
#                     '_index': 'bioconcepts',
#                     '_score': 11.44691,
#                     '_source': {'ent_id': 'Disease_MESH_C574275',
#                                 'ent_term': 'hand',
#                                 'ent_term_norm': 'hand'},
#                     '_type': '_doc'}],
#           'max_score': 14.8808975,
#           'total': {'relation': 'eq', 'value': 438}},
#  'timed_out': False,
#  'took': 15}
#
# ---
#
# #7 gastritis and duodenitis
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [{'dedup_docs': {'hits': {'hits': [{'_id': 'B7IYgoEBh99XIFUokoFN',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.021085,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D005756',
#                                                                                        'ent_term': 'gastritis',
#                                                                                        'ent_term_norm': 'gastritis'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.021085,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 192}}},
#                                          'doc_count': 192,
#                                          'key': 'Disease_MESH_D005756'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': '97IcgoEBh99XIFUoVb6s',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 11.325549,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D004382',
#                                                                                        'ent_term': 'duodenitis',
#                                                                                        'ent_term_norm': 'duodenitis'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 11.325549,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 52}}},
#                                          'doc_count': 52,
#                                          'key': 'Disease_MESH_D004382'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'cO-5hYEBh99XIFUoCfWj',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 10.021085,
#                                                                            '_source': {'ent_id': 'Disease_MESH_D014947',
#                                                                                        'ent_term': 'gastritis',
#                                                                                        'ent_term_norm': 'gastritis'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 10.021085,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_D014947'}],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': '97IcgoEBh99XIFUoVb6s',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': 'XrVGgoEBh99XIFUo0Y6I',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': '57ZbgoEBh99XIFUocuve',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': 'mLhugoEBh99XIFUoiC4B',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': 'prhygoEBh99XIFUoZW9u',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': 'Erh0goEBh99XIFUojpRi',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': 'lrh5goEBh99XIFUo7O4k',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': '7LqLgoEBh99XIFUoZBYd',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': 'zrqVgoEBh99XIFUoLLyj',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'},
#                    {'_id': 'c72-goEBh99XIFUol3vN',
#                     '_index': 'bioconcepts',
#                     '_score': 11.325549,
#                     '_source': {'ent_id': 'Disease_MESH_D004382',
#                                 'ent_term': 'duodenitis',
#                                 'ent_term_norm': 'duodenitis'},
#                     '_type': '_doc'}],
#           'max_score': 11.325549,
#           'total': {'relation': 'eq', 'value': 245}},
#  'timed_out': False,
#  'took': 12}
#
# ---
#
# #8 problems related to physical environment
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'dedup': {'buckets': [{'dedup_docs': {'hits': {'hits': [{'_id': 'DdY-hIEBh99XIFUoM9gK',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 14.033599,
#                                                                            '_source': {'ent_id': 'Chemical_-',
#                                                                                        'ent_term': 'related',
#                                                                                        'ent_term_norm': 'related'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 14.033599,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Chemical_-'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': 'nLMngoEBh99XIFUoVHgT',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 14.033599,
#                                                                            '_source': {'ent_id': 'Disease_MESH_C000657245',
#                                                                                        'ent_term': 'related',
#                                                                                        'ent_term_norm': 'related'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 14.033599,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Disease_MESH_C000657245'},
#                                         {'dedup_docs': {'hits': {'hits': [{'_id': '6MIFg4EBh99XIFUoiS_N',
#                                                                            '_index': 'bioconcepts',
#                                                                            '_score': 14.033599,
#                                                                            '_source': {'ent_id': 'Gene_5970',
#                                                                                        'ent_term': 'related',
#                                                                                        'ent_term_norm': 'related'},
#                                                                            '_type': '_doc'}],
#                                                                  'max_score': 14.033599,
#                                                                  'total': {'relation': 'eq',
#                                                                            'value': 1}}},
#                                          'doc_count': 1,
#                                          'key': 'Gene_5970'}],
#                             'doc_count_error_upper_bound': 0,
#                             'sum_other_doc_count': 0}},
#  'hits': {'hits': [{'_id': 'nLMngoEBh99XIFUoVHgT',
#                     '_index': 'bioconcepts',
#                     '_score': 14.033599,
#                     '_source': {'ent_id': 'Disease_MESH_C000657245',
#                                 'ent_term': 'related',
#                                 'ent_term_norm': 'related'},
#                     '_type': '_doc'},
#                    {'_id': '6MIFg4EBh99XIFUoiS_N',
#                     '_index': 'bioconcepts',
#                     '_score': 14.033599,
#                     '_source': {'ent_id': 'Gene_5970',
#                                 'ent_term': 'related',
#                                 'ent_term_norm': 'related'},
#                     '_type': '_doc'},
#                    {'_id': 'DdY-hIEBh99XIFUoM9gK',
#                     '_index': 'bioconcepts',
#                     '_score': 14.033599,
#                     '_source': {'ent_id': 'Chemical_-',
#                                 'ent_term': 'related',
#                                 'ent_term_norm': 'related'},
#                     '_type': '_doc'}],
#           'max_score': 14.033599,
#           'total': {'relation': 'eq', 'value': 3}},
#  'timed_out': False,
#  'took': 9}
#
# ---
