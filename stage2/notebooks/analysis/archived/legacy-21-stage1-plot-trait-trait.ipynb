# %%
PALETTE = STAGE1_PALETTE

# %% [markdown]
# # top matching

# %%
df = STAGE1_WA_NX_1_ALL
df
# Out:
#                                         efo         Model  value
# 0      http://www.ebi.ac.uk/efo/EFO_0004616  BLUEBERT-EFO  0.412
# 1      http://www.ebi.ac.uk/efo/EFO_0003778  BLUEBERT-EFO  1.000
# 2      http://www.ebi.ac.uk/efo/EFO_0003901  BLUEBERT-EFO  0.125
# 3      http://www.ebi.ac.uk/efo/EFO_0004247  BLUEBERT-EFO  0.529
# 4      http://www.ebi.ac.uk/efo/EFO_0003917  BLUEBERT-EFO  0.529
# ...                                     ...           ...    ...
# 10597  http://www.ebi.ac.uk/efo/EFO_0003769   Levenshtein  0.059
# 10598  http://www.ebi.ac.uk/efo/EFO_0002422   Levenshtein  1.000
# 10599  http://www.ebi.ac.uk/efo/EFO_0008549   Levenshtein  0.556
# 10600  http://www.ebi.ac.uk/efo/EFO_0003853   Levenshtein  1.000
# 10601  http://www.ebi.ac.uk/efo/EFO_0003863   Levenshtein  0.316
#
# [10602 rows x 3 columns]

# %%
ax = stage1_plots.plot_nx_density(plot_df=df, palette=PALETTE)

# %%
fig_path = paths.stage2["revised"] / "weighted-average-nx-10-all.png"
print(fig_path)
ax.savefig(fig_path, dpi=1000)
# Out:
# /data/ik18445_cache/projects/vectology/stage2/data/output/stage1-assets-revised/weighted-average-nx-10-all.png

# %% [markdown]
# # weighted average 10

# %%
df = STAGE1_WA_NX_10_ALL
df
# Out:
#                                        efo         Model  value
# 0     http://www.ebi.ac.uk/efo/EFO_0004616  BLUEBERT-EFO  0.464
# 1     http://www.ebi.ac.uk/efo/EFO_0003778  BLUEBERT-EFO  0.658
# 2     http://www.ebi.ac.uk/efo/EFO_0003901  BLUEBERT-EFO  0.091
# 3     http://www.ebi.ac.uk/efo/EFO_0004247  BLUEBERT-EFO  0.576
# 4     http://www.ebi.ac.uk/efo/EFO_0003917  BLUEBERT-EFO  0.576
# ...                                    ...           ...    ...
# 9419  http://www.ebi.ac.uk/efo/EFO_0003769   Levenshtein  0.135
# 9420  http://www.ebi.ac.uk/efo/EFO_0002422   Levenshtein  0.741
# 9421  http://www.ebi.ac.uk/efo/EFO_0008549   Levenshtein  0.420
# 9422  http://www.ebi.ac.uk/efo/EFO_0003853   Levenshtein  0.499
# 9423  http://www.ebi.ac.uk/efo/EFO_0003863   Levenshtein  0.328
#
# [9424 rows x 3 columns]

# %%
ax = stage1_plots.plot_nx_density(plot_df=df, palette=PALETTE)

# %%
fig_path = paths.stage2["revised"] / "weighted-average-nx-10-all.png"
print(fig_path)
ax.savefig(fig_path, dpi=1000)
# Out:
# /data/ik18445_cache/projects/vectology/stage2/data/output/stage1-assets-revised/weighted-average-nx-10-all.png

# %% [markdown]
# # weighted average violin plot

# %%
df = STAGE1_WA_NX_10_ALL
df
# Out:
#                                        efo         Model  value
# 0     http://www.ebi.ac.uk/efo/EFO_0004616  BLUEBERT-EFO  0.464
# 1     http://www.ebi.ac.uk/efo/EFO_0003778  BLUEBERT-EFO  0.658
# 2     http://www.ebi.ac.uk/efo/EFO_0003901  BLUEBERT-EFO  0.091
# 3     http://www.ebi.ac.uk/efo/EFO_0004247  BLUEBERT-EFO  0.576
# 4     http://www.ebi.ac.uk/efo/EFO_0003917  BLUEBERT-EFO  0.576
# ...                                    ...           ...    ...
# 9419  http://www.ebi.ac.uk/efo/EFO_0003769   Levenshtein  0.135
# 9420  http://www.ebi.ac.uk/efo/EFO_0002422   Levenshtein  0.741
# 9421  http://www.ebi.ac.uk/efo/EFO_0008549   Levenshtein  0.420
# 9422  http://www.ebi.ac.uk/efo/EFO_0003853   Levenshtein  0.499
# 9423  http://www.ebi.ac.uk/efo/EFO_0003863   Levenshtein  0.328
#
# [9424 rows x 3 columns]

# %%
ax = stage1_plots.plot_violin(plot_df=df, palette=PALETTE)
# Out:
# 2022-05-12 15:55:32.049 | INFO     | funcs.plots.stage1_plots:plot_violin:31 -                value                                                       \
#                count      mean       std    min      25%     50%      75%
# Model
# BLUEBERT-EFO  1178.0  0.550409  0.218642  0.036  0.43325  0.6055  0.72475
# BioBERT       1178.0  0.425172  0.187452  0.022  0.27925  0.4325  0.55700
# BioSentVec    1178.0  0.447244  0.187542  0.058  0.30700  0.4450  0.59100
# BlueBERT      1178.0  0.402374  0.185323  0.040  0.26125  0.4050  0.53875
# GUSE          1178.0  0.396570  0.185861  0.043  0.24400  0.3840  0.53600
# Levenshtein   1178.0  0.326893  0.164039  0.035  0.20500  0.3005  0.43350
# SciSpacy      1178.0  0.433470  0.183741  0.037  0.29825  0.4320  0.56050
# Spacy         1178.0  0.388220  0.188961  0.025  0.24800  0.3830  0.52225
#
#
#                 max
# Model
# BLUEBERT-EFO  0.921
# BioBERT       0.893
# BioSentVec    0.923
# BlueBERT      0.884
# GUSE          0.835
# ...

# %%
fig_path = paths.stage2["revised"] / "weighted-average-violin-plot.png"
print(fig_path)
ax.savefig(fig_path, dpi=1000)
# Out:
# /data/ik18445_cache/projects/vectology/stage2/data/output/stage1-assets-revised/weighted-average-violin-plot.png
