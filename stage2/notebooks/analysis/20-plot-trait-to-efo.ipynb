# %%
for batet_score in [1.0, 0.9, 0.8, 0.7]:
    logger.info(batet_score)
    plot_df = mapping_routine.prep_trait_efo_mapping_agg(
        ebi_data=EBI_DATA,
        batet_score=batet_score,
        model_collection=info_revised.model_collection,
    )
    print(plot_df)
    fig = stage1_plots.plot_top_hits(plot_df=plot_df)
# Out:
# 2022-06-02 13:41:40.090 | INFO     | __main__:<cell line: 1>:2 - 1.0
# 2022-06-02 13:41:41.174 | INFO     | __main__:<cell line: 1>:2 - 0.9
#           Model  Exact  Broad  Narrow  Other   Total
# 0        Manual    603    527      47   14.0  1191.0
# 1    BioSentVec    328    144       7    1.0   480.0
# 2  BLUEBERT-EFO    323    129       9    1.0   462.0
# 3         Zooma    343     86      12    2.0   443.0
# 4      SciSpacy    306    118       9    2.0   435.0
# 5      BlueBERT    276     63       7    1.0   347.0
# 6       BioBERT    266     72       4    1.0   343.0
# 7          GUSE    260     72       8    1.0   341.0
# 8         Spacy    265     72       2    1.0   340.0
# 9   Levenshtein    219     43       4    0.0   266.0
# 2022-06-02 13:41:42.261 | INFO     | __main__:<cell line: 1>:2 - 0.8
#           Model  Exact  Broad  Narrow  Other  Total
# 0        Manual    603    527      47     14   1191
# 1    BioSentVec    343    162      12      2    519
# 2  BLUEBERT-EFO    342    152      14      1    509
# 3      SciSpacy    331    138      12      2    483
# 4         Zooma    361     95      14      2    472
# 5       BioBERT    295    101       8      1    405
# 6      BlueBERT    295     90      10      1    396
# 7         Spacy    289     89       6      1    385
# 8          GUSE    279     92      11      1    383
# 9   Levenshtein    241     63       7      1    312
# 2022-06-02 13:41:43.368 | INFO     | __main__:<cell line: 1>:2 - 0.7
#           Model  Exact  Broad  Narrow  Other  Total
# 0        Manual    603    527      47     14   1191
# 1  BLUEBERT-EFO    378    212      19      4    613
# 2    BioSentVec    369    205      21      3    598
# 3      SciSpacy    353    173      20      4    550
# 4         Zooma    379    124      23      2    528
# 5       BioBERT    329    133      15      3    480
# 6      BlueBERT    331    125      17      2    475
# 7         Spacy    316    117      17      3    453
# 8          GUSE    303    127      20      1    451
# 9   Levenshtein    257     85      13      1    356
#           Model  Exact  Broad  Narrow  Other  Total
# 0        Manual    603    527      47     14   1191
# 1  BLUEBERT-EFO    414    254      24      5    697
# 2    BioSentVec    387    228      26      3    644
# 3      SciSpacy    375    203      23      6    607
# 4         Zooma    401    143      24      2    570
# 5       BioBERT    355    160      18      4    537
# 6      BlueBERT    351    147      22      4    524
# 7          GUSE    321    151      23      2    497
# 8         Spacy    332    141      19      5    497
# 9   Levenshtein    280    104      16      2    402
