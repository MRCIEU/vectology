# %%
top1_df_path = paths.stage2["output"] / "weighted_average_top1_df.csv"
assert top1_df_path.exists(), top1_df_path
top1_df = pd.read_csv(top1_df_path)

top10_df_path = paths.stage2["output"] / "weighted_average_top10_df.csv"
assert top10_df_path.exists(), top10_df_path
top10_df = pd.read_csv(top10_df_path)

# %%
output_dir = paths.analysis_artifacts["dir"]
assert output_dir.exists(), output_dir

# %%
fig = stage1_plots.plot_nx_density(plot_df=top1_df, palette=info_stage2.sns_palette)
output_path = output_dir / "wa_top1.png"
plt.savefig(output_path, dpi=1000)

# %%
stage1_plots.plot_nx_density(plot_df=top10_df, palette=info_stage2.sns_palette)
output_path = output_dir / "wa_top10.png"
plt.savefig(output_path, dpi=1000)

# %%
stage1_plots.plot_violin(plot_df=top10_df, palette=info_stage2.sns_palette)
output_path = output_dir / "wa_violin_top10.png"
plt.savefig(output_path, dpi=1000)
# Out:
# 2022-12-19 14:42:38.926 | INFO     | funcs.plots.stage1_plots:plot_violin:29 -              mapping_id                                                       \
#                   count   mean         std  min    25%    50%    75%     max
# Model
# BLUEBERT-EFO     1191.0  596.0  343.956393  1.0  298.5  596.0  893.5  1191.0
# BioBERT          1191.0  596.0  343.956393  1.0  298.5  596.0  893.5  1191.0
# BioSentVec       1191.0  596.0  343.956393  1.0  298.5  596.0  893.5  1191.0
# BlueBERT         1191.0  596.0  343.956393  1.0  298.5  596.0  893.5  1191.0
# GUSE             1191.0  596.0  343.956393  1.0  298.5  596.0  893.5  1191.0
# Levenshtein      1191.0  596.0  343.956393  1.0  298.5  596.0  893.5  1191.0
# SciSpacy         1191.0  596.0  343.956393  1.0  298.5  596.0  893.5  1191.0
# Spacy            1191.0  596.0  343.956393  1.0  298.5  596.0  893.5  1191.0
#
#                value
#                count      mean       std    min     25%    50%     75%    max
# Model
# BLUEBERT-EFO  1191.0  0.553191  0.218752  0.036  0.4335  0.613  0.7215  0.921
# BioBERT       1191.0  0.422176  0.187399  0.022  0.2750  0.423  0.5525  0.893
# BioSentVec    1191.0  0.453264  0.180614  0.058  0.3185  0.446  0.5865  0.923
# BlueBERT      1191.0  0.405150  0.185169  0.040  0.2630  0.400  0.5405  0.884
# GUSE          1191.0  0.393076  0.184587  0.043  0.2465  0.378  0.5220  0.846
# Levenshtein   1191.0  0.325003  0.164144  0.035  0.2010  0.303  0.4255  0.852
# SciSpacy      1191.0  0.431482  0.184377  0.037  0.2930  0.432  0.5640  0.892
# Spacy         1191.0  0.386093  0.186115  0.025  0.2470  0.381  0.5180  0.875
# 2022-12-19 14:42:38.938 | INFO     | funcs.plots.stage1_plots:plot_violin:37 - 0    BLUEBERT-EFO
# 2      BioSentVec
# 6        SciSpacy
# 1         BioBERT
# 3        BlueBERT
# 4            GUSE
# 7           Spacy
# 5     Levenshtein
# Name: Model, dtype: object
